# %% [markdown]
# **This notebook contains a scripts that creates a database of download links for student documents**

# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd
import numpy as np
import gspread
import gspread_dataframe as gd
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from fuzzywuzzy import process

# %% [markdown]
# **Connect to Google Drive**

# %%
gauth = GoogleAuth()
gauth.LocalWebserverAuth()
drive = GoogleDrive(gauth)
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=1017190226189-f1d5s7cpjrj54u2rqk1ufh9pevguqoap.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&access_type=offline&response_type=code
#
# Authentication successful.

# %% [markdown]
# **Authenticate Gspread**

# %%
gc = gspread.oauth()

# %% [markdown]
# **Create WorkSheets**

# %%
#2020 student files database worksheet
cohort_2020_files_worksheet = gc.open("Student Files Database").worksheet("2020")

# %% [markdown]
# **List Files in Folder**

# %%
#create list of files or folders in drive folder
def list_files(file_id):
    file_list = drive.ListFile(
        {
            'q': "'{}' in parents and trashed=false".format(file_id),
            'corpora': "teamDrive",
            'teamDriveId': "0ALGjY-PCeStEUk9PVA",
            'includeTeamDriveItems': "true",
            'supportsTeamDrives': "true"
        }
    ).GetList()
    return file_list

#create list to store folder ids
campus_folders = []
student_folders = []
student_files = {}

#create initial file list
file_list = list_files('13ovdZDNKpNfE4dj38hXH2qFwtbz_BWe3')

#save folder id's in campus list
for campus in file_list:
    campus_folders.append(campus['id'])

# %%
#save folder id's in student folders list   
for folder_id in campus_folders:
    file_list = list_files(folder_id)
    for student in file_list:
        if 'dismissed' not in student['title'].lower():
            student_folders.append(student['id'])

# %%
#save file id and title in student file dict 
for folder_id in student_folders:
    file_list = list_files(folder_id)
    file_params = {}
    for file in file_list:
        parent_id = file['parents'][0]['id']
        file_id = file['id']
        file_params = {"file_id": file_id, "parent_id": parent_id}
        student_files[file['title']] = file_params

# %% [markdown]
# **Convert Student Files Dict to Dataframe**

# %%
student_files_df = pd.DataFrame(list(student_files.items()),columns = ['Filename','File_id'])
master_files_df =  pd.DataFrame(list(student_files.items()),columns = ['Filename','File_id'])

# %% [markdown]
# **Convert Link IDs to Links**

# %%
#student_files_df['File_id'] = student_files_df['File_id'].apply(lambda x: f"https://drive.google.com/uc?export=download&id={x}")
#master_files_df['File_id'] = master_files_df['File_id'].apply(lambda x: f"https://drive.google.com/uc?export=download&id={x}")
#student_files_df = master_files_df.copy()
#print(student_files)

# %% [markdown]
# **Subset Dataframe to Contain Specific Documents Only**

# %%
#method to find specific docs
def find_files(full_file_name):
    file_name = full_file_name.split(".")[0]
    file_purpose = file_name.split("_")[-1]
    file_purpose = file_purpose.strip()
    file_purpose = file_purpose.lower()
    
    if file_purpose == 'snr cert':
        return True
    if file_purpose == 'id':
        return True
    if file_purpose == 'wtc contract':
        return True
    return False

#apply find files method to filenames column
student_files_df = student_files_df[student_files_df['Filename'].apply(find_files)]
student_files_df
# Out:
#                                   Filename  \
# 0             Innocent Sandla_Snr Cert.pdf
# 1         Innocent Sandla_WTC Contract.pdf
# 2                   Innocent Sandla_ID.pdf
# 6     Sebaratlane Mashaba_WTC Contract.pdf
# 7         Sebaratlane Mashaba_Snr Cert.pdf
# ...                                    ...
# 1849                 Andrew Cordoms_ID.pdf
# 1852       Andrew Cordoms_WTC Contract.pdf
# 1853             Aidan Josias_Snr Cert.PDF
# 1854         Aidan Josias_WTC Contract.pdf
# 1856                   Aidan Josias_ID.pdf
#
#                                                 File_id
# 0     {'file_id': '1HG6_4HaXd2lDEBYF8Z-n3jKstX6dvSJJ...
# 1     {'file_id': '155f3dqgYEdvf9HZvh-tQhvyDnkIBkUYF...
# 2     {'file_id': '1o57FHWu1uPvs8UWz1bvC1JSZVeqljL8_...
# 6     {'file_id': '1kwHFmZ8duYfKscdcT7Y1-dgZscevG7rZ...
# 7     {'file_id': '1yXH2UEEDdqF7MjlDvK3GkPSdZJgZZtTR...
# ...                                                 ...
# 1849  {'file_id': '1mygBIRivKYA152p4C8LXGs3mmBhbawT5...
# 1852  {'file_id': '10A2Azs81VmHT33PP5eq17IRC-E3uw77c...
# 1853  {'file_id': '1uHpxvywgwWGmijdB-wQZ6wuFbyLBE0HY...
# 1854  {'file_id': '1VZb34hnqSs_aOTAYayTvob8d3mVOy6YE...
# 1856  {'file_id': '11kJqojYtyl0MuEBXibMc9PapVB6kec6a...
#
# [759 rows x 2 columns]

# %% [markdown]
# **Split Filename column into Fullname, G12_cert and Contract Columns**

# %%
#strip filename whitespaces
student_files_df['Filename'] = student_files_df['Filename'].str.strip()

#set filenames to lowercase
student_files_df['Filename'] = student_files_df['Filename'].str.lower()

#remove file extension
student_files_df['Filename'] = [elem[0] for elem in student_files_df['Filename'].str.split(".")]

#split filename into fullname
student_files_df['Fullname'] = [elem[0] for elem in student_files_df['Filename'].str.split("_")]

#split filename into filetype
student_files_df['Filetype'] = [elem[-1] for elem in student_files_df['Filename'].str.split("_")]

#strip fullname and filetype whitespaces
student_files_df['Fullname'] = student_files_df['Fullname'].str.strip()
student_files_df['Filetype'] = student_files_df['Filetype'].str.strip()

#replace filetype values
student_files_df['Filetype'] = student_files_df['Filetype'].replace({'id': 'ID file', 'snr cert': 'G12 Certification',
                             'wtc contract': 'WTC Contract'})

# %% [markdown]
# **Reshape Data Frame**

# %%
#drop Filename column
student_files_df = student_files_df[['Fullname', 'Filetype', 'File_id']]

#use pivot to reshape dataframe
student_files_df = student_files_df.pivot(index='Fullname',columns='Filetype',values='File_id')

#remove column 'filetype'
student_files_df = student_files_df.rename_axis(columns = None)

#remove index
student_files_df = student_files_df.reset_index()

# %%
student_files_df['WTC Contract'].values
# Out:
# array([{'file_id': '1C7g17p3ZGdifgxYA1Ej8uv0HOrcJCyN7', 'parent_id': '13QrdFDlWkhdTo1Eus031e3hf5dtUlXRW'},
#        {'file_id': '1v2FE2qdaTl3yHqnc5cOxNME4GFEWoskI', 'parent_id': '17ZoNVnnE1nXx0RBWa_z-LH2acgnVR0w8'},
#        {'file_id': '1tLuQ4IYLvZN_l75U_Ew7xy8kPX5if3SQ', 'parent_id': '1IY2VD1Tjrp-sSAh2ydkTAEKCm1OMAtY8'},
#        {'file_id': '1S4nEgPOn26HEFvijtBaFzGnspqAyzBf3', 'parent_id': '1cvTA0KbK27LJixsLq7Wcm9ZtSF59Zzbx'},
#        nan,
#        {'file_id': '1Odj94GM31Va8bAXVqfIB49yLRkQUTVh_', 'parent_id': '18gA3lQlfHiSi_8Fqf17BGgnOSs6Szvv1'},
#        {'file_id': '1VZb34hnqSs_aOTAYayTvob8d3mVOy6YE', 'parent_id': '1GUU-6-DLCl81L14WjKJ5lEXhdhwzYKD7'},
#        {'file_id': '1M9qEhRO39gdyhmRyCBPWHcQ7HZPb_lCA', 'parent_id': '1AQ_8ymUMoJ3xdVoA4GEptXOfmrZTt7jH'},
#        {'file_id': '1UKoMGrZpe53urAR4fv8o5Me4KQPyVpvx', 'parent_id': '1SkC0uEx4ajIB54JOpo18v2iYMcDlGJav'},
#        nan,
#        {'file_id': '164Z8Z0ZyoTt1wSffZ3gUN-XlY3n8Tari', 'parent_id': '1RXpqlVKVIno82xqehud0G0h939FCevww'},
#        {'file_id': '19WCf0GatT5gjV23efZg6HKAo9GX-OAdX', 'parent_id': '10-7I9DGsEHiDkClaFjSmleZjncOrbmC9'},
#        {'file_id': '10A2Azs81VmHT33PP5eq17IRC-E3uw77c', 'parent_id': '1lVKUfI1PUsS5JGz57uEKyUC_N6-TiHgR'},
#        {'file_id': '1qAnm_w1kkFq2jE4AniOjQKIG8c9ZVf3b', 'parent_id': '1sQT6hGOOSSWXwvWQi88lfC0wD788yJsh'},
#        {'file_id': '1BSfUonP_o2w_gbuWdNUwjjjP4tGaaJHF', 'parent_id': '1-ji6umMowmij3GkBRWsac4xHydsOh52p'},
#        {'file_id': '1Zbf0pKqeOvMwSDtOgUbUZdBCbW8ZA-2r', 'parent_id': '1-39ywNPxTpDQSq6CtjL2KrBTPb8DDvGB'},
#        {'file_id': '1XNq4y9JBftzhp9Xuw0ACfJFzpbXW6o7x', 'parent_id': '1Eex1NN-UuvrX6TRpC7km-8_51hkoaF96'},
#        {'file_id': '1MGysCqlkpniL1cMrdNxwb-QAWhUO-3h4', 'parent_id': '19M-elkSH9HUGJfNWVRbBD9jCh2TF41q-'},
#        {'file_id': '1komLPXK18z8hPlDZAG33emeyH0rXG_7l', 'parent_id': '1z9n-2jEc3fnXBu2yxgdg9Xc8XbGA-wZt'},
#        {'file_id': '1xUqERhYVvmrW5KqIoEd3bBchghdYHMPx', 'parent_id': '1gU_VJomUfRlPKuPBClodFSH2hUTKUcue'},
#        {'file_id': '1pgX9ovT_8BPurHEJzJpHgbZEWRepGUQh', 'parent_id': '1bh9PtTL1NgXHmXlMudv9ga5K_2PeuPgV'},
#        nan,
#        {'file_id': '1hH1Zb3yIKzgAf4SXfmc_AdxB7lUdA-gl', 'parent_id': '1qe8aaAR2D3IxjX4BdckaWf_4_uIpghze'},
#        {'file_id': '1pe2hkzrnr2HcXOY02xejJ3azf4yk3iQ_', 'parent_id': '1cXuwJfl3f7lgTZ5iKhe1W0r5ah6d2Ocv'},
#        {'file_id': '18lkR0ItHq1mfY14VzTngCh1esa7xRiKV', 'parent_id': '1AhN5-bcORvANU4heAi2HS4Aam7JgjYfp'},
#        {'file_id': '12arPB5fMExol9Q8ZuBFEoXB50WNpQ3IG', 'parent_id': '176Y9RjTKjEsglDhCB7wwe75NUPFjsago'},
#        nan, nan,
#        {'file_id': '13DIpF5ui3j4-3IHoWgVsRv2WajRCWAZ2', 'parent_id': '1N9ihCiJqt7XslEZAelL4DMWbnKVob99m'},
#        {'file_id': '18kBcbuFoHdiACi-cSTFEjEdhhrzgd0rd', 'parent_id': '1fzjvOiR0FPXpdaxO_8Lcqr8xHI8wTLQ4'},
#        {'file_id': '1vT4w3-Nbg6D14KY4ZFYift6ptlImWDbT', 'parent_id': '1efKX4dJNrU6ec5hB2m6SO6pPr3M4pfxG'},
#        {'file_id': '1mQhoj-EaYLaRNnrmTI_CM4EbhdCYiSNS', 'parent_id': '1Wp37jpBeopX48cuLaFnunHDvTNzA1LTY'},
#        nan,
#        {'file_id': '1dGOPb0AH60UrDrGLdQeZcQ9fs1ixFKxK', 'parent_id': '1kQnIYsXm63ItbxkI4cJEy0Q8lmEmUGya'},
#        {'file_id': '1Mo7YQlSPNy2p3cXN1lk0S6ACpTjq7Zff', 'parent_id': '1fE4Y7ggcIyCxZQeyYozYcddOKmzZkzof'},
#        nan,
#        {'file_id': '118Osrn0dCaIo6Xn60VRTKe85Wu4TzDuv', 'parent_id': '1VrnbpY_XT4WqTusTezS6-QUHjFCY_o-3'},
#        {'file_id': '1uBXpm7SosOwknp_eunY9MAwpigC8LaJV', 'parent_id': '1OfoY8zz05ZoQ0IMN0O4fNHXDd7mdMt1h'},
#        {'file_id': '1TrQYDx80js1RJhQZ37aExUBazO8lGbw5', 'parent_id': '1h7vfA4czD1_UNqikaLt1BGwlnEBZcpPS'},
#        {'file_id': '1-yTTHaZlSZyr633zvwC62UquOuaVwA4R', 'parent_id': '1za3NEKwimsgTjZZLToi3yAfXtvX6Pg1U'},
#        {'file_id': '1ZhLeJ61k1drS9MhinSugonqhzPNvotUP', 'parent_id': '1yLyV3oD8BWd02f79EIoFoodpPw5IlQA5'},
#        {'file_id': '1-D9rxvW6VKTxvhnVQNrwMwl-nJwDo95Q', 'parent_id': '1cNa3MXqv8z5zCn6kslWbPsGiDy-ZcXH7'},
#        nan,
#        {'file_id': '10_yrm-CNS2JgKRPvoqJfxEK-SJccqnIr', 'parent_id': '1p3q7fFKw_qua7JIWJn9KWKKiPHr3xHZG'},
#        {'file_id': '1j457JK94rjPyxRkE-PTnxZ4U_EYyekSt', 'parent_id': '1Set6BFEMNYP0XNB713ohrsefwe7bfSDa'},
#        {'file_id': '1PQz1GFDpSKZBB_yP29h--i0dD5ajXJrp', 'parent_id': '14D1YSbpif9IbIE_GWUJzZA6PFwhmkyTd'},
#        {'file_id': '1Md3xIzN7ynhwfPYHW1hRNF0Q_rbvHxQw', 'parent_id': '1z0-GZpwynk4Ix1Rf9TIeTKqQRYK_W7uJ'},
#        {'file_id': '1iIGlgXD52XnB3aQT-M2A_Da8Lljl8-rf', 'parent_id': '1mOEC5VrxPpO9lEV7vhFWYBkpltkBkfnU'},
#        {'file_id': '1r-GW5jD9eaXlv3eIDihY8rE2wjLXwMoG', 'parent_id': '1bLxiAJ1IRn4GVz3IcjX1niYi4MxEZuB5'},
#        {'file_id': '10pTvBX3Y920kSN4FlqOkztILMbnE3qjf', 'parent_id': '1RG1_XTJmTha_y91zne7xtN30uRKlij8L'},
#        {'file_id': '16EmV95fMc5NGaUS3rwUOPfpG04LMDw6g', 'parent_id': '1q7YE0LbdWFdo1P-zlF8QbWRK-6mOK4Ld'},
#        {'file_id': '1ADsrZyEl4vpTwvbfowY5XbdQvh9owrm5', 'parent_id': '1MBT19psQ5YyR_NH9N2Ex-rw7WYuQueQN'},
#        {'file_id': '1L-kxhIn6u1Is4BpsXgxvZ4qut0BuP3um', 'parent_id': '1vU8uDpC0clL-W4nFLB9U1JZF1viacV24'},
#        {'file_id': '1k3T1yEIdfg0GAdfCuQ3gOgxS9SuHin2B', 'parent_id': '1bAB-CzHQ1b8UAsYTUVfZIGbnbmKYNAvB'},
#        {'file_id': '1fn2z-T0f98KcxQW0JzIGg9_KjhY_UO-2', 'parent_id': '1GtZCS1dDUTn5m2RjNC-44HwS-I9mRTnJ'},
#        {'file_id': '1TCaHRtbW8N0FTV2xnJ41_NXz7tKCdIR4', 'parent_id': '1KoN_kZzJsrDH2ulSwHKqB_93K_ZnzP4p'},
#        {'file_id': '1f3DGYHTd0Oq7K_cgbaQSTTVZQsx1XaSm', 'parent_id': '1g2CHqEcCBEY9ldGUTIvpwIWNFzUzKrPL'},
#        {'file_id': '1wLeFmYeW3v77THv8bYMoVkIFLwFf84YX', 'parent_id': '131acuthsJlOT3-K3eEw5oE_xDjnCO-XV'},
#        {'file_id': '1BqSoomT7GWEH1U-oGBmBXLZnwlu4tJ9S', 'parent_id': '1wrIrgQTTkD3TtRSBAaZLhvTmSiigetfO'},
#        {'file_id': '1q22M04tQYwlq73S9eqUKFHZ2sQ8SNuJh', 'parent_id': '1wfT4Why4RvCuZPbmuhNFQXG9r5g8sIZN'},
#        {'file_id': '1bTp1fM29lmN9BdcGMaeFpD0JId-tpFN3', 'parent_id': '10iOLjclxKDzWMK53AUK9FVZqGesAJe88'},
#        nan,
#        {'file_id': '1dI1wAEXQR81SKFRGBmxm5NuT34wU4Uc7', 'parent_id': '1NhLKiYAamUHoOvTWOhpzrOQXiH1Kqwdv'},
#        {'file_id': '1D8MlLLJtYaZ3EJ0f6IlC0S1Q06YTH1f9', 'parent_id': '1wDYtHoyKNP8HtAfUrCzek6fLkzaSEoI_'},
#        {'file_id': '1el5Li1MPcEDKzDKkUloEYlTwT29eMzJu', 'parent_id': '15eClkdHHtVbyOPYDgky7ex4x9QQ8ZpFi'},
#        {'file_id': '1K-Ux8pF3vhGWQeaSAfQdwa0y1e0HUH61', 'parent_id': '19fgCslXyTInFKcxYOdiLXA2H8mL8EBxU'},
#        {'file_id': '18eS3QyYpjW2mrCidDvssbqNb9BI-k2HK', 'parent_id': '1uJrKIB-U2fKdKj1lcX7hwxuNFt5s92p2'},
#        {'file_id': '1mOcRAyVvXjt7NCsmCEdKy9UXip78NVHz', 'parent_id': '1DHk2WXriGHPPdze3dkonA8VuQm-NZ8Ol'},
#        {'file_id': '1WgKei9wSXTGgeCEwKw2_T5R5cMCwThbo', 'parent_id': '1R5CSUIBm4FqegkdpRh4X7mclehQtlSn4'},
#        {'file_id': '1dgn8x0fNMA_cu068UcIOuF_QbFLJ--Il', 'parent_id': '17DOY3BNYdEbeFHBybKY9qmbNKRRaN498'},
#        {'file_id': '1yHJfQxGhqhkWLzYUf3vjUG2CLZBp5bCy', 'parent_id': '1MA84DxJTN8LNay5NsOk9cPDgg7A4DJ7L'},
#        nan,
#        {'file_id': '1LCPbwJtHcllNnVisbKrDgBeS2RwEstkm', 'parent_id': '1LtwHuSXaL1ufY-cZ7DUtSIu_iWWj0C4R'},
#        {'file_id': '1NMxjJt5HqtF9bkBrQTqtPJE4VaL62kq9', 'parent_id': '1U4xy1IJjgAHbVGcjWnnzfwbdzDfXEobp'},
#        nan,
#        {'file_id': '1cewRMqX29qv8k_AtnHnrIeH7DJcfmnou', 'parent_id': '1l2MEWE51xJTls1Oy8xLjhCY9mW9inqj_'},
#        {'file_id': '1AhBRwfoCDHKmfS_-acTi2Yatq4dRX7X0', 'parent_id': '13PYN7f69_PntzXGPAvXPDuFicgagJYTl'},
#        {'file_id': '1eWAmvvriXNKVURunnjq0_ABqixqnHDGX', 'parent_id': '18RecH1Pgx3xqfSVtPVPpyRECR76V3g4r'},
#        {'file_id': '10l_OZ97TW2TweS1hu2Tksi7_XRK_0sL7', 'parent_id': '1WJ6umsV9SM5rPgxQSWEC6f1iiXZORRiP'},
#        {'file_id': '155f3dqgYEdvf9HZvh-tQhvyDnkIBkUYF', 'parent_id': '1j-__w7fhADl1gI_4PekDySSMPZ-mYt7A'},
#        {'file_id': '1SLfMNzMETF6LhkJDttA6Gspwq_FaN3AO', 'parent_id': '17CKUXz-jYLzdHHXNvH6X_XYboW2A9ktO'},
#        nan,
#        {'file_id': '1zoEcBdqFeyRzTYZhIVXl-ai1vofeX4ie', 'parent_id': '1GBr3bl7FvKknh0BDbpucvDQ6Yix8UzA3'},
#        {'file_id': '1jJYIYj77QBaCgvjpRxlY40XbGyfK8n2e', 'parent_id': '1NTFHw2P8AFzhFUx97Lt-9P44vtSzLtZL'},
#        {'file_id': '1yoKd41sZXJebNkkgRnxZHf9GqOb_cy1p', 'parent_id': '1GCfUQlokgzM_z68-QjqwqK6Yn1Rn5UG4'},
#        {'file_id': '1j06C1R8iHa0DxdsI-LrAC5K4pgzKQ5Ki', 'parent_id': '1HGznHmsvPz1jAzr88H5krIGHaO2vcm6I'},
#        {'file_id': '1ZeeyKJj43W-Wwu87B2joc_P0JkvB4RNO', 'parent_id': '1NLE1hCajixTijiIEeE8_-pTlczyb9Zni'},
#        {'file_id': '1LUoq83fi4tRKl5Z9T80mSsI4-VEIq_11', 'parent_id': '1pn_TKkQViAiANUCYhf7BryGzHcl55W9p'},
#        {'file_id': '1e71WpGPIXw1y18OTyH1_H7CW_xYD7B40', 'parent_id': '1F6ocHvlxnPv_wBG18Ew6pFdtiMPerphu'},
#        {'file_id': '1awNSIzfGOsjEXdnzhcKLd32FMemLaQcM', 'parent_id': '1iFqjgSWegUHbfgWF6q77NmnHXMoefLu7'},
#        {'file_id': '13riSpfLGWMpPU4JBokD4Bz-j7T5TNJVs', 'parent_id': '1WljPz6XfNoVw5-qUskuXFq_nJFM3E7SW'},
#        {'file_id': '1JfFSpeHzh_nPK3fGZK5YRxm6RiSTw7p4', 'parent_id': '1vxMYwERGeGxWLEoYlshrSRikFWPBmfoP'},
#        {'file_id': '1JWOXg24venXmQPt9bv2idzhzT5AEdZ-M', 'parent_id': '1XYDnqP29TbjlwFONnjQ0xPZHdMgG7s3S'},
#        {'file_id': '1jaQjR60m5gDI1w8kSOh7vSkRSAXKOYnH', 'parent_id': '1m6lTTSvUDzTKz2rnf2KAZfhgQlqS-4GW'},
#        {'file_id': '1iTryAo7s6A6jGIbj2jagdt4EMIkVFDyC', 'parent_id': '1_re03ztfwbkRibIG2CP4kGEpQXrziKP9'},
#        {'file_id': '1FHkh125LRMzTRaB2Gr0aXDLV46oPq1d8', 'parent_id': '1ybDqTygXZl2B1qvgFkiV1VNmxB9k0iBi'},
#        {'file_id': '1FQ44UMwvPjFm8ohjzzvyQ3zFHvdWnerj', 'parent_id': '1ngVxG5XlNljtN6HfbIlxm8dZ4J7rN0GL'},
#        {'file_id': '1ynyaO7Nwk0uGCgTVr9HZkmMk8dp5WZQ0', 'parent_id': '1ArXNH4sbFhcuBiajHBbEozndCRDi7iji'},
#        {'file_id': '193rK3Qm6S00nhbtiHyU-2qlcicBVsHsn', 'parent_id': '1P0GWTalGQ2Ttv9GHENl_sfJHvsHZ7VBt'},
#        {'file_id': '1vD2O3ORTZQHUy5lVMUpbwDcFxF_mRZNx', 'parent_id': '1b3eo8chTMXqzmeYz4NgOMYP17kmk84Zp'},
#        {'file_id': '1aWCLvnV1BrwSyi-3lqtMm6QuPcDZyWq6', 'parent_id': '1HOY3lEHOSMNm3TGm5uPOSzBlkmfHaqbo'},
#        {'file_id': '1kqxT0W0t_DoVQkOUMgzJ_YFRpqXfpHM9', 'parent_id': '1Gsw8GxUN9p93-nygd_xlJdGX1bF68rL4'},
#        {'file_id': '105hfyx6dFcB3NVGAMBbSLBnsHwuOUBLS', 'parent_id': '16gt2VBqIECIBQGfvujiRR_Xh-L7BU09K'},
#        {'file_id': '12cCsLYL4iz-Z23xQcDKRh7XDmGm6vTpG', 'parent_id': '1lvTL2CDRuN9DsajoHyJeDlKGX5gpw1EG'},
#        {'file_id': '1Vg42NTBQfsy3dDCJaG-oAxoZ-T3x1Wjg', 'parent_id': '1g3OCLpGHkEcPg1S1yUEOtm_4L3aHEcNf'},
#        nan,
#        {'file_id': '1JBYZYSdZwekmgOc3Rci5YsmXTSHenJIZ', 'parent_id': '1rjnwSsU0ESBCNRHTHbiTzPUTHPOxUJDE'},
#        {'file_id': '1Ue22q5ODL4xhJg1LPcnOEqwf1CdJTghb', 'parent_id': '1Jz2ZT7kl1EByRsAZFbbZDKFQ1O0ssyqR'},
#        nan,
#        {'file_id': '1sTqV_SD3s3szXoQe_o-bskGPCHyULAMV', 'parent_id': '1ncrlU58EsfT9MSz0OMcCofmMokpoMUEu'},
#        {'file_id': '1vBYH6lFGgauMhMJum-O2ph-VDE_R1hYv', 'parent_id': '100KtOd2Wq_-VyW2Cixt6wcPCx7BvfTAD'},
#        {'file_id': '182-ky1In3Jt1YbWnCZ2Vkc48gjt1FXum', 'parent_id': '1xrnTn6DSPc_LvAkukb-PRBIM8Yfv6SiD'},
#        {'file_id': '1DBZzJOBO5f7TyCGffCRaijwFXjznR1ls', 'parent_id': '1hTdELmhMzbRz7dVo3NW_6UreHQemKJl8'},
#        {'file_id': '1bhu_q1gpKPOMOkz7zQ38dLu0W1bx1lDT', 'parent_id': '1y7TMbe10Br5TjXnQgjXOJFtGzbQjjL3w'},
#        {'file_id': '1SXUYx1Eo7MYadG3TTlsyT4FO9k4r6IXF', 'parent_id': '1kWX6D03FAfgrtNWcqILSgyN7wHZIq3D8'},
#        {'file_id': '1N8gsJ3OgX1hMASV1wfxb2XFNvHxMnffT', 'parent_id': '1glnyumMXE9NxQQdtAGTeSeJHtLMEy0IW'},
#        {'file_id': '1QqYoQpmeTMHvQg0p-sJnCTzk64ewfLw_', 'parent_id': '14cPlTOxIIw_a0NY0NYi25R7x0wpvncyD'},
#        {'file_id': '1lWI-IRKGHXsHV9THaAz0HfwljU4FBZKq', 'parent_id': '1SVlUtWqygChAuZ8KJXsKDH5im5yx2iER'},
#        nan,
#        {'file_id': '1Q_8mCqvV2ykyyCK-KZT6IWBh0EXK8XLU', 'parent_id': '1q9PlJOGzS7PWFuajgi6Q_I332xe_gdp1'},
#        {'file_id': '1AAMgrqjbjlksoFb72NH7W3Zj2OOwq2X7', 'parent_id': '1Oq--6x74-u63AQRhISfl349BcSl2m7YI'},
#        {'file_id': '1ihEmE0ItfLKSsDPF0ismf5I4Rfexagx2', 'parent_id': '1XvrCG8v7OhC5uDKvjeEMPcZps6FjRn5E'},
#        {'file_id': '1VMimXpNw2z2Kh0_629PH9t8HAd3GNfZW', 'parent_id': '17sXIAPIMJp_HtQUNJE7QN4yMY0QaMZC_'},
#        {'file_id': '1z1NZvFBOITQVjTTMXjc19gZhdEm6C6xK', 'parent_id': '1aHCIeJP6Yw5Zx3SNWLoUFBfgFU8IJpFn'},
#        {'file_id': '1DtddvANaUoqXH57-QYFyXWflJaooh5U2', 'parent_id': '1HjUZsDIscGLSturqkuOC6-PsyGlhCQEV'},
#        {'file_id': '1dPPvftP8PDIS0erRnxQQmPc_vD6Id8Tq', 'parent_id': '1bmiMCuVK1DDX_mp9pZrQrqa8acHR7Ahk'},
#        {'file_id': '1cmXP_Ih3rp5gpFL6gxSoZm7zKuhtRZu6', 'parent_id': '1RZu74jx4Zx-uOOfDcQ9fMIxk-Vn9Bvn0'},
#        {'file_id': '1XnUNm71IZyfzwbkqh86s0AGSGDkC1QK2', 'parent_id': '1-RKY1QlH8QELBStR-DzSYr5VgkUXnv2m'},
#        {'file_id': '1ieqlzn_k_GN6YZtw9wFFePIt4XfpklVK', 'parent_id': '1MGzzjcaHPYc5_qIICaIKGK3THQ-sNfpF'},
#        {'file_id': '1x-WNcoK6Wh7D77-yrAcwamorof66qo4T', 'parent_id': '1vmm3soGiO3YsUsPktdfmSWV6X_BjXBmv'},
#        {'file_id': '1-HnJctDd5I-I0uNxIGbux-BfraPvmV4-', 'parent_id': '1AyhHZRs0aEJ47bScylt4-AsRw82Vtf9Y'},
#        {'file_id': '1EDuMMtl1mGaPRAfwaRPoNITptlraQpBg', 'parent_id': '1xe2US173oVZmVhEF0e9xAYSWzjlGrsg0'},
#        {'file_id': '1lZAfve6XPRGqU10AVbMukfHNfBTD8vQl', 'parent_id': '19ErW7KQUs8icuUzJdYWkVPLcje0AulcY'},
#        {'file_id': '1gYysjo3SHpMmFq_ty23jfm9lZuOF4lbE', 'parent_id': '1-d7vneuQPUQblZ56Zi4li0R3s4in4Pgy'},
#        {'file_id': '1ds1n0-33SEN64vZtJX8bRFbReDBxb4Q-', 'parent_id': '1QQmDQ7DA5A_MLcYyAQ40UTs82n1kPi0u'},
#        {'file_id': '1f0IhEo2KhMWwbWEFyhC-bGeh8TxelpZA', 'parent_id': '1HeuPKxtNWdJyVhwIqlQOwFM4VGgMuG87'},
#        {'file_id': '1Y67qmKamYiWeCIiNiIrf-xYLjqNNtsM6', 'parent_id': '1EJxAediL-Z5db7lX5avb1BUbCsLZbJo8'},
#        {'file_id': '1YU_PON7KvMfH-NoZCsSZ9yJZemz7r-8b', 'parent_id': '1tEP_xjlSNXTbmLYB-LIOoRxPXv-EpODH'},
#        {'file_id': '1fhpu9STvsYt9SdneWToSm_LPkeKbuC_a', 'parent_id': '1R2YHjsn5wU2KC4-ekmbv_74V1rSPhvtI'},
#        {'file_id': '1Iw_JrqMRX6UiSoLp-e2oj9flOsZKAVlx', 'parent_id': '10EBkNOhjPGoQvfH5KMwPO8CP4qznwfDV'},
#        {'file_id': '1UoPOjKQsJJJUG_3EyrnC-XSDchZT2zcp', 'parent_id': '1LAkzveOzeXGq4z47sWjL84u7qEQmTwLi'},
#        {'file_id': '15S2ityOe3bg1gnKdrMhDrkM1wP99GGJs', 'parent_id': '1GWp1l1lcBmqDkkkYf-4o1YRBnjDfyRVX'},
#        {'file_id': '1zncH7cC-yVhhdTpetEem7EjbCbWdfftM', 'parent_id': '1QlP-J0Ez9eaaS3RQFHqDXx7t7Mnaqmcf'},
#        {'file_id': '1YOflAFiNVsf4BurN5ebtd9DtNvLa8KxJ', 'parent_id': '1vmbkWiUE53MG_UOnjcMAMrcOjI4yNbQY'},
#        {'file_id': '1_srATkBRgdVb-RhV2LpLi2AML-s7VPdC', 'parent_id': '1aqMrmlIrqLDYVDOWQp6Rz7NVcy2qVbhR'},
#        {'file_id': '1ubKmvr1lLn8MZv_y2z1w2H2noWfn6WOg', 'parent_id': '1ml606-8xKrUaWgpbfz1WTmxhUyJlBS4L'},
#        {'file_id': '12XXyacfuyqTsvJRx8Rqc-qHAhgMzXqWL', 'parent_id': '151oIBQhfme4ZzI7ouHJXSlVEKDAq36ZA'},
#        {'file_id': '1zL06q7-f2avhyX8H6Y9nBPm6ysJzyyxa', 'parent_id': '18rxzltyooVGlZvo0F8uBw47kwBG-8UZE'},
#        {'file_id': '1nC75okO2vvultprdWrI6GqWpwpnwsbYE', 'parent_id': '1v7vXNQOMPMbo6Wk1IB59orjIkB4h3W_i'},
#        {'file_id': '1BwmYilhDG4Ntu6GTv__5h4Oc06C5Jt1O', 'parent_id': '1WnEgnoaZfObDvBHfhKKk9U0ECLtzc0Ru'},
#        {'file_id': '1yJlaL-0EL_4yuG8lPZ9RUwf-YcDDjqSx', 'parent_id': '1WJOwpQPdz_MwlFpAxlEqTRENGhwKyp1U'},
#        {'file_id': '17J6luRDDcPQdfhqkSj_XbKAkIIt5tpvm', 'parent_id': '1xTXYeEb0mDjmAI7HH-b5qxdN9bHi0UFY'},
#        {'file_id': '1OKk8g44e02I3CyIDK8dhK12nuV4SB8hs', 'parent_id': '16r0j28IPON1_LF533otI3-8lK15wpYwO'},
#        {'file_id': '1yhz0lsZf_Q04LGmj_Wra_Q4XCmdREFCs', 'parent_id': '1SdyXaNaS6TS8BT5GHq60YWY_l0VD7swq'},
#        {'file_id': '1QRCS8J-os3Ke_wHUb97K2wlpI98tZEa1', 'parent_id': '1vJm5d_bjgFzbHJkl67MUiY2FJ3sxkxFl'},
#        nan,
#        {'file_id': '1Dmwggp3HV_xQiE9717V8iSt1mFo420a0', 'parent_id': '1i5I6RtQjxvzwPwQMWwZ1zTl_zkvsgNt6'},
#        {'file_id': '1JFYrtpp2EathlfcqFi9UV6W4lgJt1H6C', 'parent_id': '11sCqgxxFvfHBiepGb8RjlvYFOsqz57ny'},
#        {'file_id': '1HLuz3Jw66ZH7hmmObo3bzu4M4s7BMNhl', 'parent_id': '15vAl76f49qt8UDBHVt9lMIutrlzyQW0Y'},
#        {'file_id': '18uT69g2LpO4RZiG1krbpOmFYTpM_3Jyh', 'parent_id': '11Vm2vDrDfC5O5pOGo9Dfb6MoWe50FgYF'},
#        nan,
#        {'file_id': '14scd_j7jHqi7B7HBmtn0O8UO6xnXVveM', 'parent_id': '1ww-BWQmkuY7HyRj1WSwGJR_SnBlt8x9p'},
#        {'file_id': '1OY1f4QVXGXd_-KAIaetfp9XFkIJ-HOki', 'parent_id': '1cqJsGlaP5vtW2cGKiX3AFkZq5fDw-4ns'},
#        {'file_id': '16YGuLy4rpvaka4v2jxTKaYeLFpXIp8Mh', 'parent_id': '1l-9pcwlnISko9cYXKTKBM93ivPzi-jCs'},
#        {'file_id': '17xwttL5KLQH0ScR9mCdX9aDkOFmU3vpX', 'parent_id': '1buZJH5J_JkCMEIkvUGjM_zALF2ADwghx'},
#        {'file_id': '1Ihgp-QkMtkUBOO7_0YuaFqhsfooc6juy', 'parent_id': '1GycR1k47OjfzPqZ_RJ_zp1UvYN21ceL3'},
#        nan,
#        {'file_id': '1-kYbaeA68H_Z_y_AHaKqexBAez8MaOqk', 'parent_id': '1jdXrmwDLPgcQh1PfoSgx5zv4gJrj3inE'},
#        {'file_id': '1F-QEG8bwl-cZSUojT907USXXbrswJ_j7', 'parent_id': '1idqzAGawgVU27uqpmx6BODC2lZrBPLaT'},
#        {'file_id': '1i4rXPf83G0hNoJ4JV5rO_vNROer9OAmP', 'parent_id': '15sEI-FHY5862xbCwZ8zYfv8MR3PsptWd'},
#        {'file_id': '16DCngN0p3C7iEFxeR8y-dF4Y9f7UEj3W', 'parent_id': '1UBPv5wY-BkbPn-ydZShm-A83V6QYkXOS'},
#        {'file_id': '1BZ4as43rPuwbHQynQ-zESi4J7vQhQ4nj', 'parent_id': '1rp4Kb_Z7NMLRRmLgGcXjQDqDyIrToi_2'},
#        nan,
#        {'file_id': '1oBKaOILBADhWBzxu3zm7DMAAdYGGV9I0', 'parent_id': '1it_rUNEDS5Mcd1Xqkm5B2PUZ4v-_r3hL'},
#        {'file_id': '1dZycj78suRSUmskrtTaVgMTA-vcroOpE', 'parent_id': '1SQ1dPM6acBsJ-paaojK0ZV_X7okpKMJU'},
#        nan,
#        {'file_id': '1St4Hzu3iKFozHoao_M9qQfYwCXZiGdwX', 'parent_id': '1-7TIrstOOdz6Q1sdBNbex1sgBhjqI2d6'},
#        nan,
#        {'file_id': '1GTGGbSGGCxfLKs1XspqHLfmXDSgLGfTP', 'parent_id': '1voTGRRZ4VTgIldHXCt5iO8ggxqLw5ckO'},
#        {'file_id': '1RE_WvhMxJPe6lbvgek8kETS5OaO8TvOx', 'parent_id': '1xDXkXET_QXOLEJBymkxtU7fvkZwiiLXQ'},
#        {'file_id': '1TJu1k8qPEs5tdK6k507cKBqTAy8YN3Fy', 'parent_id': '1vpCUlN9KZRN1JxqfJ_4bseVE1SetCZFt'},
#        {'file_id': '1BMxzcI9ZxJamn6yhK8iDkVC80kveItfX', 'parent_id': '1wZy7kXC2QntedoqwKGztOOxjuYj9KgCP'},
#        {'file_id': '1u2XFd0dW0K9p0l8gtmhsWkc4H13aDDxK', 'parent_id': '1JZ84MK9nZPB846OAapErBx-CVhoncVL5'},
#        nan,
#        {'file_id': '1k-roH79TKg72TH_wSGgszOnMBmqSjEqE', 'parent_id': '1w4TPqAYZCTbYHtqyke0EG6XC-FGuY3_U'},
#        {'file_id': '12YBnm-UOtrNk7tEk803yAjX_CEb1Yz4d', 'parent_id': '1DcjTW_ai7Y2Pz7mMBUDAuKw7fX_d8sqa'},
#        {'file_id': '1OIudh-56-MDNW6njyZprI1iyB9fD9TzK', 'parent_id': '1Lk1Qy5mDVSb2Xyw_kdLNILSpO3T0mKx5'},
#        {'file_id': '1Q_l4tbxKpxAwR6qq4XOGT_LRiivxZfDZ', 'parent_id': '1DAiNLHkEW6ivOWitZBXeSBN9q_gYgxiL'},
#        {'file_id': '1lRk139gKEvJR17dzmeDuxDpvRMZU4Sn6', 'parent_id': '1-T1bZPE_jtLHUE5vUTHBJZIqgkHV9R0s'},
#        {'file_id': '1PlPUFTN9P2x5FFhWIOstD3WlBxdsSPa_', 'parent_id': '10x_6wwxkaxuKMS0uuqnghz6SBh00xR-f'},
#        {'file_id': '1AEfTLtm1lsjIz_2nkWj7-QtkL2_LEuki', 'parent_id': '1X-z0X5_h70FHd1G0Bs_LXq0i8rdhkFv3'},
#        {'file_id': '1q53mLfqY5GQ4wiTLCrJZwt4jZkM87gkx', 'parent_id': '1gmeQ1gfiiBwavy-jxrwEjKCmeuosri7l'},
#        {'file_id': '1UrM8yWdr1rWHPxU6YTyt6mlgqUmUYLY7', 'parent_id': '1EFsCu8o0--BUB-Oe567lFLzs3KOjK54g'},
#        nan,
#        {'file_id': '1pRO-MLDtKkz_XrgspgtcBx2FxOA_8YCy', 'parent_id': '1w1TtPszhQev9ueJOF1lVPU-6vvO65qQX'},
#        nan,
#        {'file_id': '1TaCATeHXqkZd27dpg_bhPY8GcLJ0iKhX', 'parent_id': '1ptCJ5WRHEK-IOVA8XBq1tpGcgpXXW5Zl'},
#        {'file_id': '177lJX-f2IkznhdpZw712BcC1APi-kgPb', 'parent_id': '13Er8w6rY6cpfDU1a6SKq8xKsE0Jpusjk'},
#        {'file_id': '11KSQcR5ZenqlVTQ6_g2N1TYeil_tro5k', 'parent_id': '1GsEoYTLn5S4P64UqTmAls2BMPGogEG8z'},
#        {'file_id': '1tnl9WT_TCUV6YcesWOWdJiqyw6Obohx2', 'parent_id': '1VcHzLwmE1jqMs_i5P5KBZyhuLturwdFy'},
#        {'file_id': '1tlOo24BKRKwzyuvRa5RNezac8iNLKz_w', 'parent_id': '1Ts41puxnv9bSdEvzykB1rBhHaSFmnpqN'},
#        {'file_id': '1zHvZXC4G4e28452gFFaWfmA6ADHlSBUI', 'parent_id': '1Y2sE40w-B8N-140a3JiNLDNSDBAx_ymI'},
#        nan,
#        {'file_id': '1iyKJXeSy1IuU3GeGWB1BC-Cq25BlaDNg', 'parent_id': '16rccnz-zToGuor4uZZ1S1ROLgY2LCIAr'},
#        {'file_id': '1IY6R3gfEkjL58z5tHD79ZIfmFhpNkCzp', 'parent_id': '1Ce1e4MItVcE2aDVaxTVYCCMx2CNtsmrL'},
#        {'file_id': '1Wud0c7oVBCXVOCXIscUtY1W-WFaiqYDW', 'parent_id': '1ZXAxwnISr0hN2rUTEX1Oae8EhH6G0xxp'},
#        {'file_id': '1c7PQDu45qCD1ye4em0n5qyJCi86ydgko', 'parent_id': '1PFRqrulfqxC5FTwXN9uK9tCT5HUZuXrN'},
#        {'file_id': '17ZeSHj3T1NPeNxdoQHV4hDMBcAhfBE2i', 'parent_id': '1fa-7axM6fkSPTxixctJKCm116fOA5KLV'},
#        {'file_id': '1eaARPb3-sld61lWeEZUzLHlWmzWgFUVb', 'parent_id': '1h0TIFgo7JVpPo5m0JMsLogZSxffyeLhU'},
#        {'file_id': '1IoQTm0AzsAhP2djgSZ2tPbHpplbASrWj', 'parent_id': '1JG4-JDexCF_ja_zndFNqUvstC9SByxC7'},
#        {'file_id': '1F1ABor9YkEvS2GK00KlqTdjkOhRRVCYN', 'parent_id': '1tdOFNKR_o2urFr4HaLzNtvI-RFcTv9L_'},
#        {'file_id': '1xbYzyxNlczpmQBAql8eennR9Q_4u3ZrF', 'parent_id': '192HtAsuZieygZ8ggfqRAdGTK7g0BihXx'},
#        {'file_id': '1sGwQpt6tz-FYBEfEwAuB5f3zkD7zI7Gq', 'parent_id': '1qfMpbtSvIhd8eN_Nr_4MrBk1wDGcGgaz'},
#        {'file_id': '1950xipXSUW5mOkDvSpXreFcIN4DQe5Ip', 'parent_id': '1INUjQ60vE5sBReR-AjMV27HW6hRgJ-Sn'},
#        {'file_id': '1hS0djnWC7fGylPiRTn5CufFF3qDwUWyq', 'parent_id': '1cYKJ92WVh6eTvhIVSWZyhic3Ad8T5vV-'},
#        {'file_id': '15Z1x5LuzA2zF5rSkRZCBBKYGyeq2cKI_', 'parent_id': '1qp4bnMkaqmrtEhjTnYM_3UWI66PAgx43'},
#        nan,
#        {'file_id': '11K5nBq-Bo2Sw7B5sUWBOA2H1EmQqRgfg', 'parent_id': '1r14Tm41evgutHs0iA9kljyxOxdu8JEu_'},
#        {'file_id': '1_F4-j_ippiIoVS-AYnwMsppuNFIA9_PG', 'parent_id': '1OuvGt33dFpEoHcdrbtbhLAqjO5oU5Irw'},
#        {'file_id': '1TzgpLObdSTOrYr6KinCZOmnoVy-ZCvNi', 'parent_id': '1U_zR81ShiZ36yswRICOPXNqfTkyeY2Ax'},
#        {'file_id': '1gbaMTBYHyzVRyxvB5Hi07kft5uGMQZeS', 'parent_id': '1z4Q-dFYLwzQ858JleTtUga4DFDPEo4Bk'},
#        {'file_id': '18FCkZctqqZ1VdJplyFuZeBk8UdLKCa0t', 'parent_id': '1tUOGWyuu71qxMumKyflOr-QM3NPh3dF_'},
#        {'file_id': '1M6TEloD7ZbFkFf5KvCu7uLMiwChkVloa', 'parent_id': '1LvMsEKPwtcE9irANjOe7c904aVNJtlzK'},
#        {'file_id': '1lDmAM_bocVHIrNPUUOlwID0_94N4wveV', 'parent_id': '1ES8jq3qhaSd_QjEHMahqIgGjGGXZ3vig'},
#        {'file_id': '1XG3qObKGtceB9MVPfJmHFMTJsBF6hRKa', 'parent_id': '1BdgxUwtFI8aIsA8t8i6idd77chMI593W'},
#        {'file_id': '1rOuJeOTgUDWaZmkMFMV3x7jSKmzCoDPL', 'parent_id': '1kQT1K6CQoX3FSlNUpmkHqpbzgBrifXF1'},
#        {'file_id': '1LS-1WwfhudHASVjf-YzmthvKN4xlX_Ii', 'parent_id': '1F6pZ0HmNzKuGOv1d5aiDLBx4iu0Oesqd'},
#        {'file_id': '1BqpKJNsW9ft6pb6DEf0ObCQtcEziLU6_', 'parent_id': '1X0t-Y62qulfj4og8rLZ5kSG0UqaghE1y'},
#        {'file_id': '1n5-5X1qDPaDZj3vOKfs0u3-3AHSvIYbO', 'parent_id': '1ac-1MlHR6RmW5JWhCKuu6OFiVLj6btgr'},
#        {'file_id': '1kwHFmZ8duYfKscdcT7Y1-dgZscevG7rZ', 'parent_id': '1YyASodGiLEDKHbnpvBmendqsZy12X-Rr'},
#        {'file_id': '1O7KKEjy-YTDeM3sPUr3aY2LcSB_WHB0K', 'parent_id': '1AtIA6YZdln6W7ujA0A_MFm5kvcrYwhLG'},
#        {'file_id': '1RPcZN8HrdgvZ_jlTGnL5MJV0BkxKKWGd', 'parent_id': '1-d0Wg1CgJzdAw5oFzsPOf5i-YrIlYyvE'},
#        {'file_id': '1xyOS1somBhwCJVxEMbgsJoDM34lAFM9e', 'parent_id': '1wDh0JPweZwi4u_1f8YrcKKbX4OqeoOUG'},
#        nan,
#        {'file_id': '16kyJng5F3tYLYwkPyrKyNTlYQG9APgeZ', 'parent_id': '1oMlVS2iF91SPRMsoKTHvmF2RsGQ4ZlHt'},
#        {'file_id': '1bpqtFveptCP95Nyino96WNSnZgV1QdB2', 'parent_id': '19xywmD_AEFgv-4IsR3LOpOQq8JJ00-qy'},
#        {'file_id': '1eXzhQcOVIBGsRIYhUvgNQggqG-QBAKYZ', 'parent_id': '1DRhBz4OG4w2TJgX8BchGGo6nUbMx9cJV'},
#        {'file_id': '1PS35v80zr5aZ3VihwCaw1E_GbA6sG6R3', 'parent_id': '1MkMyEoyUZhNCYn9my4eCWJpxZAsNpBqJ'},
#        {'file_id': '1ky1cBdOLs9IfN2YjOivj4Cs0f2sj5aiy', 'parent_id': '1EdWa2RdBBAC2r3nXNrypju0bsXOeGpzQ'},
#        {'file_id': '1AQLGBSS8DJvwqPlgbOXhdXXUGQ_HOzzj', 'parent_id': '1lOo_mhX0ZsUQnbG6RRa8NhAAr0Punzk1'},
#        {'file_id': '1ZIkoZnBJyZxzV0db_Dxil49G9k4mvP0y', 'parent_id': '1eIOnXcuA2vWkg9BAVeMXijf65-LzF7MA'},
#        nan, nan,
#        {'file_id': '1MwXWMZ6ZICmQabLVKaxdqXHv0r6mhygr', 'parent_id': '1gpHrh3UW9Fxhsqk7ep6DbiM7KazgTPmn'},
#        {'file_id': '1g-Pl2Bi5ODfTnyJKvNbtv-uR2caOLeFh', 'parent_id': '1-Fts_OTbpMUiwCAUwe8wmPc7lJWfZELg'},
#        {'file_id': '1-RPO0uxkd_ZijhHpZRVmBTcGGxY15u-Z', 'parent_id': '1V2omFNDVcO5Nl5GBmxgA1j48vLJKs95t'},
#        {'file_id': '1mMSyEvJgR-ylbj9QShgqXJLlk5U0gAir', 'parent_id': '1xdDCNqlkhyqQn3TbZp5X8aLzhN7IzCuC'},
#        {'file_id': '18MG6-xvutVk3SPhcK0RFwtqTXgpNsXnN', 'parent_id': '1_lh-kdjU7OEUxYXwqa1xfig6uLUFrCcX'},
#        {'file_id': '1LyUICq81dm38RHAexz_yV8ojDv3FmG-Z', 'parent_id': '1-m4WfzMtx1PgDCwwT9IP9WH5L_oeBUWU'},
#        {'file_id': '1V8iBKb5lGHudg4ZNZjUpbX-GHxY9ahSl', 'parent_id': '1VeqobkzwY0aD-BTlY7YnmZcLeZ8Eq7_-'},
#        nan,
#        {'file_id': '170jw5-eG-ZImmy-eIybZ4Y7d5A-COCn6', 'parent_id': '1O2wcHb66JjpYt3h1t89s7OnePGDx44Dg'},
#        {'file_id': '1GaowLPEiCSeSlP4DIZ31MQUUXgTXbd1D', 'parent_id': '1AI9PrgREZcJCWKS_aW95r_GgzfdbpGio'},
#        nan,
#        {'file_id': '1R8T7OjGU-NRSPHKxLdLhgv9OEV27bfWS', 'parent_id': '18mmjQp1WeR6v-HSl449CM3-3GvYtKvrD'},
#        {'file_id': '1ZrN2OLYCef9GWOeiSh1mqF9q_Pj3xW9d', 'parent_id': '10QR21RDgDCsIXgx-E5dc4W9ROU64fR4n'},
#        {'file_id': '1fEWqyh3wbfS8IACxS-Y5vYcyqDDFCGjP', 'parent_id': '16oW3FdIkltenQ5HGhj8WU8tCRqv0-uiY'},
#        {'file_id': '1kLnVEH5AWpV6D2H0qF09L3tJ1Ht82orn', 'parent_id': '1W26sP-VAwyAG7S9ckdwvaqFRNQ0vSueH'},
#        {'file_id': '1-yGztuAmVtJ34UV2MQI1sWHtbhL0-ajU', 'parent_id': '1OmkGyAHKE2ZsLlz7UhmOVqjAjbF8AVhO'},
#        {'file_id': '1bDeX0mBNtAXnrMD-7-o7d8z2Hkw0cgfZ', 'parent_id': '1EXWCiOPMZaPKKf6Yf82fmE7lHUc7XX7K'},
#        {'file_id': '1zyB7Lf7l4qUCNm1U6Bq1-2qVDpPYiAfA', 'parent_id': '1QQfa_dkdwb-cLASCjZz-xWyQfnC3sJWh'},
#        {'file_id': '17ynEVBBU_uAxDVnzLK4jsyDI4O6mlFC1', 'parent_id': '1-7QUcAc3t4Am0tbZIA4_0ZSEaVK_OINo'},
#        {'file_id': '1ru8-1LTZcOCuhaa4R6yEvslaN2lA-LLy', 'parent_id': '1pRzuB087WXBWiImz30fvTJlX634SvjYw'},
#        {'file_id': '1rbTjIDWnElgIBvfOdW6nZtVQLf9Vb0Bc', 'parent_id': '1lyCK5T-P8r-b-8pDljWzb9YccZbLiSFg'},
#        {'file_id': '19sFSe-yrkBjvT9UX9apQsauoRf5oIkKh', 'parent_id': '10SmOVFS56JhZ-bQt8Ppj9bYrP7WxOp1q'},
#        {'file_id': '1vMYtUL61scSikC1CeVWBGKLzsVd_-NPg', 'parent_id': '15QEz5jFZrbv0B9Pky-jMVNmZfdm_Mv5E'},
#        {'file_id': '1gmq3fp9vcgPLU0eHKJ1UmjmUpqBCDcob', 'parent_id': '1zdnD0XBqCc6Ibt8xb_tTG9Q1xFBOccSR'},
#        {'file_id': '1QLmqeiUqP4Mn2VFCdA2SUfZ7aeLYJj-4', 'parent_id': '147eVceevk8v4B99QoigpQ0q1K7hbVKHD'},
#        nan,
#        {'file_id': '1W7AuXgIP6LjHfj7wxX5xgE3V7zywFFnv', 'parent_id': '1SZk741mcdNFmJFVIytWdZVyKIQ52L_Y9'},
#        {'file_id': '1V_qrRJX6X1Um4GjrGIez4LY1WNA3h-Q1', 'parent_id': '11ySMSPrYh-UekuGK-sidF3O6KseJmSiM'},
#        nan,
#        {'file_id': '1IE5UDa_1LRXj1Ayh71FuYKS3rrg6Cu7Q', 'parent_id': '1WTVYI8Jjhg8VkAPRBNOCGv8TVZnzfYuA'},
#        {'file_id': '1CcDbPAbsqt6OEWXBqaPrY9mLYskFkqZx', 'parent_id': '1clCgqzMIHYs2EXQQW8BhHwJwZTRcLy-J'},
#        {'file_id': '1WLq01PaQYZ0TM9ml7hyb92DlYFrocujp', 'parent_id': '1J9wO8VHwis3GAtor-axqZieYq5Lc0dSY'},
#        {'file_id': '1FA1oCarzA5BkbEhlim2JbV_FLepYY9bQ', 'parent_id': '1uKFMrPDHKdkg5MwZ93wAUQwELIl5ZwKg'},
#        {'file_id': '1Kt35P0w_OBWAD1G9SJJIotWS1JCn4-D7', 'parent_id': '1QP0xJsMu_8uSeYW_XAyseyhKvJyXl9yW'},
#        {'file_id': '1N-T1AAvL2dZyEOBGd1vidFfaXf4c_ww9', 'parent_id': '1moTFYkKV0i8a1UaPKwh5Wkrox-MJpVf6'},
#        {'file_id': '1KyXiTh8KoAYSbKhc02n-QCKfdcBJKoy4', 'parent_id': '1X_DfrxrNo8B2X6y8gmaSqBtsqlgdVkYh'},
#        {'file_id': '1ZyiMTfSEWel8aUui5uMIwse-d7rszQqz', 'parent_id': '1IjOJRNrSEUC6uD8rOuAyiJ7d9VF6cZ-1'},
#        nan,
#        {'file_id': '1JgzIHTt4E8olk3ImxUr9UUA7BQRPw5kt', 'parent_id': '1GmeLk2c-HNXEGR0eXrLcOAclwfrt2kAx'},
#        {'file_id': '1Z3ugtFPTk9QkbISRHNvBIARv8BUp1V-J', 'parent_id': '19YU5fqAw6xLgr5VLzsIHPcp81ykwv8Mx'},
#        {'file_id': '1AMKPVWF26lDuCrRc7RI_KtF5ygmtFyKd', 'parent_id': '1-PoW43qo4auuGze-egJzJnnrglNOJMnM'},
#        nan, nan, nan, nan,
#        {'file_id': '1KlM1Xo6fGYyyVFIogxvTCBZWtWWWfOYw', 'parent_id': '1Lkt4_ATzJP4K4DpbSl9r9WlRq-dKtN34'},
#        {'file_id': '1XElluNnaPTbf2hULXYIYU0TtQzK6dC1U', 'parent_id': '1Gky6hpf8cYFkmjhuj_dQVmE1z29SXZgw'},
#        {'file_id': '15udIEqYNCN5WKvo0oc6HMgf1bZ_WgQjY', 'parent_id': '1HVWRhPffzfoL03huBpRLCbX8H9KwCa17'},
#        {'file_id': '1AVEbD6VwM09No73hIryD83BaqdBbuejw', 'parent_id': '1NCBlFWrmxrN5LE15X2wby5l9SOh2G1br'},
#        nan,
#        {'file_id': '18Jqk_M0TZalSl4Ym0Do6jIhSZkZigSUi', 'parent_id': '1DsXfOK3NoEfoVTcXi8yVDPdI_v4sxEC5'},
#        {'file_id': '1EFaqVnl7lgwS5OHk1D4mvTurMXYDAL16', 'parent_id': '1P8QuZCMY5JqQozEzhdM6KMPEQDkY7QIj'},
#        {'file_id': '10tCzhl7UN3rNkq9gGUTgGrg3RBvhtvG2', 'parent_id': '13gY44zwYnosVYAq9sgVjwAMQy0mg_FMV'},
#        {'file_id': '1DO5gXrVsug7WVlRWpaMj3q318eMK_RLb', 'parent_id': '1vcn_3mzmOPh887uapcRcmJBtZFyL11JB'},
#        nan,
#        {'file_id': '1qkANQbPgOnFBz52Sc7AoB56ZmY3rzDDx', 'parent_id': '1WvR_Cb5NxkC522U96juWMIFdVeyoN1Mf'},
#        {'file_id': '1GegHiMnn6g_8hjL0A1n__UCPX3RyWVLh', 'parent_id': '1t70bEDARDamlNtk-QJMLsCOe6r9MDj2G'},
#        {'file_id': '1VgioBm-VNAZgKuxULkEVoHiei0cydDD2', 'parent_id': '1nTfPk9pgsXcGbbnjGe3G41--ZD8fxPZ0'},
#        {'file_id': '1eW6tyHszUXvKSaW0VQkpjqqi9hyGAH1e', 'parent_id': '1qhLCqUkJ1Uber6mUNcH_7FldvtrL2fb4'},
#        {'file_id': '1NSqEgloMC9FPPv5LDt0PRoPH_oW7uMaN', 'parent_id': '1dUHUMMzj7voELDKgBZBePqeQDp_LSvZB'},
#        {'file_id': '1SrrgNeaYkEd_UHcWGYQJ4vRBXDjUq50t', 'parent_id': '1AI9kBz4po2G7h15jVuq1AawI8bPyCnPg'},
#        nan,
#        {'file_id': '1uAv6mKKbkvKN8NMG7SHNrwNhCp8AOvfn', 'parent_id': '1Bjh4L5VB8sPTwnPNmMafUxAfm64r-tg0'},
#        nan,
#        {'file_id': '1C8thyP-2qb5VFK7Sx0OCg2jMfxeXXnz4', 'parent_id': '1dtER4G4sueSNyYE0lvMrWxUEBc2SsEiH'},
#        {'file_id': '1s8NcheJ0Bux5FAdi84oHCINZNlorzqcn', 'parent_id': '17QbB3i3TKWO6ZPGfT-WoIPcV-CpO0j49'},
#        nan,
#        {'file_id': '1JHugkyYcRKTXPrxuL6-1lC29_4iXh2r_', 'parent_id': '1iKXcAO9uorOuzJxicy5izFJoqsFNt1Tj'},
#        {'file_id': '11wlopcWwnj2aIteABEaVEtDAtKuoLT5J', 'parent_id': '1k_xqU8GT5ftepIYvTQLJ0hbnxItBggDw'},
#        {'file_id': '1Ra5fLw43yIiVZzd_UUmv-ofttBVL6Nl8', 'parent_id': '1KZmD1hUWIc3ctDiSZSQ9Ry_oYNXkH4lf'},
#        {'file_id': '1qnlMlhQQKuN6ZhwsxCWjwhv4BUem4z7U', 'parent_id': '1fchdxNG8V6JI8LkVd_P-0X_pcvuxNlpp'},
#        {'file_id': '1sDyKdL2azOZ8ktt7zoH2lpgJ2d_4ZgpN', 'parent_id': '1Puno4qizMOrjnIQmDG0NYxY7_Y5N-9ns'},
#        {'file_id': '1K9yXGxW4ScoFY34s0G5Oc9DzoThSPVGi', 'parent_id': '1eegdLjuWtkIH7potTK0_IQzsDdAzShPS'},
#        {'file_id': '1o52lcsfBTtIghIWcdEPwAfQ4Pn1xZ1ae', 'parent_id': '1Ne2gaB0d3TLlXeXwSjkutdql1PbneJFf'},
#        {'file_id': '1g9UCne3TfLfcEm6LX4E-ZjbRq0giehFZ', 'parent_id': '1p9HAI23nRfgPXkAek0YVo6Zr0-wE3dK5'}],
#       dtype=object)

# %% [markdown]
# **Search for Missing links**

# %%
'''#function to search master sheet for missing links
def search_link(name, file_type):
    last_name = name.split(" ")[-1]
    last_name = last_name.strip().lower()
    file_type = file_type.strip().lower()
    for file in master_files_df["Filename"]:
        file = file.strip().lower()
        if last_name in file:
            if file_type in file:
                id_list = master_files_df.loc[master_files_df["Filename"].str.strip().str.lower() == file, "File_id"].values
                if len(id_list) == 1:
                    return id_list[0]
                else:
                    return None

#search for missing contract links
results_list = [search_link(name, 'contract') for name in student_files_df.loc[student_files_df['WTC Contract'].isna(), 'Fullname']]
student_files_df.loc[student_files_df['WTC Contract'].isna(), 'WTC Contract'] = results_list

#search for missing grade 12 certificate links
results_list = [search_link(name, 'cert') for name in student_files_df.loc[student_files_df['G12 Certification'].isna(), 'Fullname']]
student_files_df.loc[student_files_df['G12 Certification'].isna(), 'G12 Certification'] = results_list

#search for missing id links
results_list = [search_link(name, '_id') for name in student_files_df.loc[student_files_df['ID file'].isna(), 'Fullname']]
student_files_df.loc[student_files_df['ID file'].isna(), 'ID file'] = results_list'''
# Out:
# '#function to search master sheet for missing links\ndef search_link(name, file_type):\n    last_name = name.split(" ")[-1]\n    last_name = last_name.strip().lower()\n    file_type = file_type.strip().lower()\n    for file in master_files_df["Filename"]:\n        file = file.strip().lower()\n        if last_name in file:\n            if file_type in file:\n                id_list = master_files_df.loc[master_files_df["Filename"].str.strip().str.lower() == file, "File_id"].values\n                if len(id_list) == 1:\n                    return id_list[0]\n                else:\n                    return None\n\n#search for missing contract links\nresults_list = [search_link(name, \'contract\') for name in student_files_df.loc[student_files_df[\'WTC Contract\'].isna(), \'Fullname\']]\nstudent_files_df.loc[student_files_df[\'WTC Contract\'].isna(), \'WTC Contract\'] = results_list\n\n#search for missing grade 12 certificate links\nresults_list = [search_link(name, \'cert\') for name in student_files_df.loc[student_files_df[\'G12 Certification\'].isna(), \'Fullname\']]\nstudent_files_df.loc[student_files_df[\'G12 Certification\'].isna(), \'G12 Certification\'] = results_list\n\n#search for missing id links\nresults_list = [search_link(name, \'_id\') for name in student_files_df.loc[student_files_df[\'ID file\'].isna(), \'Fullname\']]\nstudent_files_df.loc[student_files_df[\'ID file\'].isna(), \'ID file\'] = results_list'

# %%
'''#function to search master sheet for missing links using variations
def search_link_2(name, file_type):
    last_name = name.split(" ")[-1]
    last_name = last_name.strip()
    file_type = file_type.strip()
    for file in master_files_df["Filename"]:
        file = file.strip()
        if last_name in file.lower():
            if file_type in file:
                id_list = master_files_df.loc[master_files_df["Filename"].str.strip().str.lower() == file.strip().lower(), "File_id"].values
                if len(id_list) == 1:
                    return id_list[0]
                else:
                    return None
                
#search for missing 'WTC' contract links
results_list = [search_link_2(name, 'WTC') for name in student_files_df.loc[student_files_df['WTC Contract'].isna(), 'Fullname']]
student_files_df.loc[student_files_df['WTC Contract'].isna(), 'WTC Contract'] = results_list

#search for missing grade 12 certificate 'Snr' links
results_list = [search_link_2(name, 'Snr') for name in student_files_df.loc[student_files_df['G12 Certification'].isna(), 'Fullname']]
student_files_df.loc[student_files_df['G12 Certification'].isna(), 'G12 Certification'] = results_list

#search for missing 'ID' links
results_list = [search_link_2(name, 'ID') for name in student_files_df.loc[student_files_df['ID file'].isna(), 'Fullname']]
student_files_df.loc[student_files_df['ID file'].isna(), 'ID file'] = results_list

#search for missing 'I.D' links
results_list = [search_link_2(name, 'ID') for name in student_files_df.loc[student_files_df['ID file'].isna(), 'Fullname']]
student_files_df.loc[student_files_df['ID file'].isna(), 'ID file'] = results_list'''
# Out:
# '#function to search master sheet for missing links using variations\ndef search_link_2(name, file_type):\n    last_name = name.split(" ")[-1]\n    last_name = last_name.strip()\n    file_type = file_type.strip()\n    for file in master_files_df["Filename"]:\n        file = file.strip()\n        if last_name in file.lower():\n            if file_type in file:\n                id_list = master_files_df.loc[master_files_df["Filename"].str.strip().str.lower() == file.strip().lower(), "File_id"].values\n                if len(id_list) == 1:\n                    return id_list[0]\n                else:\n                    return None\n                \n#search for missing \'WTC\' contract links\nresults_list = [search_link_2(name, \'WTC\') for name in student_files_df.loc[student_files_df[\'WTC Contract\'].isna(), \'Fullname\']]\nstudent_files_df.loc[student_files_df[\'WTC Contract\'].isna(), \'WTC Contract\'] = results_list\n\n#search for missing grade 12 certificate \'Snr\' links\nresults_list = [search_link_2(name, \'Snr\') for name in student_files_df.loc[student_files_df[\'G12 Certification\'].isna(), \'Fullname\']]\nstudent_files_df.loc[student_files_df[\'G12 Certification\'].isna(), \'G12 Certification\'] = results_list\n\n#search for missing \'ID\' links\nresults_list = [search_link_2(name, \'ID\') for name in student_files_df.loc[student_files_df[\'ID file\'].isna(), \'Fullname\']]\nstudent_files_df.loc[student_files_df[\'ID file\'].isna(), \'ID file\'] = results_list\n\n#search for missing \'I.D\' links\nresults_list = [search_link_2(name, \'ID\') for name in student_files_df.loc[student_files_df[\'ID file\'].isna(), \'Fullname\']]\nstudent_files_df.loc[student_files_df[\'ID file\'].isna(), \'ID file\'] = results_list'

# %% [markdown]
# **Search for Misspelt Names**

# %%
'''#function to search master sheet for misspelt names
def search_misspelt_names(areas, strOptions, student_files_df):
    for area in areas:
        highest = process.extractOne(area, strOptions)
        if highest[1] > 70:
            condition_1 = student_files_df['Fullname'] == highest[0]
            condition_2 = student_files_df['Fullname'] == area
            index_id = student_files_df[condition_1].index.values[0]
            contract_link = student_files_df.loc[condition_1,'WTC Contract'].values[0]
            cert_link = student_files_df.loc[condition_1,'G12 Certification'].values[0]
            id_link = student_files_df.loc[condition_1,'ID file'].values[0]
            if contract_link is not None:
                student_files_df.loc[condition_2, 'WTC Contract'] = contract_link
            if cert_link is not None:
                student_files_df.loc[condition_2, 'G12 Certification'] = cert_link
            if id_link is not None:
                student_files_df.loc[condition_2, 'ID file'] = id_link
            student_files_df = student_files_df.drop(index_id)
    return student_files_df

#search for misspelt names in the contract column
areas = [name for name in student_files_df.loc[student_files_df['WTC Contract'].isna(), 'Fullname']]
strOptions = [name for name in student_files_df.loc[~student_files_df['WTC Contract'].isna(), 'Fullname']]
student_files_df = search_misspelt_names(areas, strOptions, student_files_df)

#search for misspelt names in the id column
areas = [name for name in student_files_df.loc[student_files_df['ID file'].isna(), 'Fullname']]
strOptions = [name for name in student_files_df.loc[~student_files_df['ID file'].isna(), 'Fullname']]
student_files_df = search_misspelt_names(areas, strOptions, student_files_df)

#search for misspelt names in the g12 certificate column
areas = [name for name in student_files_df.loc[student_files_df['G12 Certification'].isna(), 'Fullname']]
strOptions = [name for name in student_files_df.loc[~student_files_df['G12 Certification'].isna(), 'Fullname']]
student_files_df = search_misspelt_names(areas, strOptions, student_files_df)'''
# Out:
# "#function to search master sheet for misspelt names\ndef search_misspelt_names(areas, strOptions, student_files_df):\n    for area in areas:\n        highest = process.extractOne(area, strOptions)\n        if highest[1] > 70:\n            condition_1 = student_files_df['Fullname'] == highest[0]\n            condition_2 = student_files_df['Fullname'] == area\n            index_id = student_files_df[condition_1].index.values[0]\n            contract_link = student_files_df.loc[condition_1,'WTC Contract'].values[0]\n            cert_link = student_files_df.loc[condition_1,'G12 Certification'].values[0]\n            id_link = student_files_df.loc[condition_1,'ID file'].values[0]\n            if contract_link is not None:\n                student_files_df.loc[condition_2, 'WTC Contract'] = contract_link\n            if cert_link is not None:\n                student_files_df.loc[condition_2, 'G12 Certification'] = cert_link\n            if id_link is not None:\n                student_files_df.loc[condition_2, 'ID file'] = id_link\n            student_files_df = student_files_df.drop(index_id)\n    return student_files_df\n\n#search for misspelt names in the contract column\nareas = [name for name in student_files_df.loc[student_files_df['WTC Contract'].isna(), 'Fullname']]\nstrOptions = [name for name in student_files_df.loc[~student_files_df['WTC Contract'].isna(), 'Fullname']]\nstudent_files_df = search_misspelt_names(areas, strOptions, student_files_df)\n\n#search for misspelt names in the id column\nareas = [name for name in student_files_df.loc[student_files_df['ID file'].isna(), 'Fullname']]\nstrOptions = [name for name in student_files_df.loc[~student_files_df['ID file'].isna(), 'Fullname']]\nstudent_files_df = search_misspelt_names(areas, strOptions, student_files_df)\n\n#search for misspelt names in the g12 certificate column\nareas = [name for name in student_files_df.loc[student_files_df['G12 Certification'].isna(), 'Fullname']]\nstrOptions = [name for name in student_files_df.loc[~student_files_df['G12 Certification'].isna(), 'Fullname']]\nstudent_files_df = search_misspelt_names(areas, strOptions, student_files_df)"

# %% [markdown]
# **Convert NAN values to NONE**

# %%
#convert g12 certs nan values to none
student_files_df['G12 Certification'] = student_files_df['G12 Certification'].replace({np.nan: None})

#convert id file nan values to none
student_files_df['ID file'] = student_files_df['ID file'].replace({np.nan: None})

#convert wtc contract nan values to none
student_files_df['WTC Contract'] = student_files_df['WTC Contract'].replace({np.nan: None})

# %% [markdown]
# **Create Column Containing Parent Folder ID**

# %%
for name in student_files_df['Fullname']:
    condition = student_files_df['Fullname'] == name
    temp_series = student_files_df.loc[condition,:]
    if temp_series['G12 Certification'].values[0] is not None:
        student_files_df.loc[condition, 'Parent ID'] = temp_series['G12 Certification'].values[0]['parent_id']
        continue
    if temp_series['ID file'].values[0] is not None:
        student_files_df.loc[condition, 'Parent ID'] = temp_series['ID file'].values[0]['parent_id']
        continue
    if temp_series['WTC Contract'].values[0] is not None:
        student_files_df.loc[condition, 'Parent ID'] = temp_series['WTC Contract'].values[0]['parent_id']
        continue

student_files_df.head()
# Out:
#            Fullname                                  G12 Certification  \
# 0  abdullah ebrahim                                               None
# 1  abdur-raheem lee  {'file_id': '1x8pKVL8q4UtkVOI6EB3mNTQW1ftVh0NU...
# 2   abigail hlalele  {'file_id': '1drznpNwHbj4q9P3BpONLG7SX-CpohVKT...
# 3       adam becker  {'file_id': '1d5haUDWJFo6gEPUjHMR9djJOJG-w_sFr...
# 4        adams wren  {'file_id': '1hBNdjBTjTcI01z3twXcJNhVqJncPJjlW...
#
#                                              ID file  \
# 0  {'file_id': '1slAYT2SdS0AOLAYse8RLPu6vaMCgO7ui...
# 1  {'file_id': '1tNyYGleV59vFuzwdjsQF4bIp5QEVdB3c...
# 2  {'file_id': '1Kb_29so7-BqhK2K4A7nt83te3bXaoscM...
# 3  {'file_id': '17G0RyMw5xxul4bofHMArFVdF5l1uFEo_...
# 4  {'file_id': '1mljxufELpRpqLc26NNiPzBJyw20rwZDE...
#
#                                         WTC Contract  \
# 0  {'file_id': '1C7g17p3ZGdifgxYA1Ej8uv0HOrcJCyN7...
# 1  {'file_id': '1v2FE2qdaTl3yHqnc5cOxNME4GFEWoskI...
# 2  {'file_id': '1tLuQ4IYLvZN_l75U_Ew7xy8kPX5if3SQ...
# 3  {'file_id': '1S4nEgPOn26HEFvijtBaFzGnspqAyzBf3...
# 4                                               None
#
#                            Parent ID
# 0  13QrdFDlWkhdTo1Eus031e3hf5dtUlXRW
# 1  17ZoNVnnE1nXx0RBWa_z-LH2acgnVR0w8
# 2  1IY2VD1Tjrp-sSAh2ydkTAEKCm1OMAtY8
# 3  1cvTA0KbK27LJixsLq7Wcm9ZtSF59Zzbx
# 4  1Bjh4L5VB8sPTwnPNmMafUxAfm64r-tg0

# %% [markdown]
# **Function to Unpack File IDs**

# %%
def unpack_ids(file_params):
    if file_params is not None:
        return file_params['file_id']
    return None

# %%
#unpack coontract
student_files_df['WTC Contract'] = student_files_df['WTC Contract'].apply(unpack_ids)

#unpack id
student_files_df['ID file'] = student_files_df['ID file'].apply(unpack_ids)

#unpack certification
student_files_df['G12 Certification'] = student_files_df['G12 Certification'].apply(unpack_ids)

# %% [markdown]
# **Upload Dataframe to Student Files Database**

# %%
#export cohort file ids
gd.set_with_dataframe(cohort_2020_files_worksheet, student_files_df)
