# %% [markdown]
# **This notebook contains a script that cleans up the SETA POE folders**

# %% [markdown]
# **Add Local Library to Path**

# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    sys.path.append(module_path + '/local_library')

# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd
from local_library import list_files
from local_library import create_folder
from local_library import import_worksheet
from local_library import export_worksheet
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=1017190226189-f1d5s7cpjrj54u2rqk1ufh9pevguqoap.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&access_type=offline&response_type=code
#
# Authentication successful.

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive

#authenticate Google
gauth = GoogleAuth()
gauth.LocalWebserverAuth()
drive = GoogleDrive(gauth)
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?client_id=1017190226189-f1d5s7cpjrj54u2rqk1ufh9pevguqoap.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&access_type=offline&response_type=code
#
# Authentication successful.

# %% [markdown]
# **Local Library**

# %%
def delete_google_drive_file(file_id):
    """Deletes a file on google drive using a file ID"""
    
    drive.auth.service.files().delete(fileId=file_id, supportsAllDrives=True).execute()
    return None


def delete_google_drive_files(folder_id, allowed_documents):
    """
    Deletes multiple files from a google drive folder
    
    Args:
        folder_id: A string representing the folder ID
        allowed_documents: an array of strings representing the files not to be deleted
        
    Returns:
        _: A boolean representing success or failure
    """
    
    included_documents = []
    files = list_files(folder_id)
    
    for file in files:
        if file['title'] in allowed_documents:
            if file['title'] not in included_documents:
                included_documents.append(file['title'])
            else:
                delete_google_drive_file(file['id'])
        else:
            delete_google_drive_file(file['id'])
            
    return set(allowed_documents) == set(included_documents)

# %% [markdown]
# **Import Data**

# %%
cohort_df = import_worksheet('POE Folders Compilation','Folders')

# %%
#Test
#cohort_df = cohort_df[cohort_df['poe_folder_title'] == 'Chantel Annah Skosana']

# %% [markdown]
# **Execute Main Function**

# %%
for index, row in cohort_df.iterrows():
    #log beginning
    print(f'{row["poe_folder_title"]}: Starting Cleaning')
    
    #delete alien files in presentation module
    allowed_documents = ['evidence', 'instruments','presentation_review','presentation_feedback']
    delete_google_drive_files(row['presentation_folder'], allowed_documents)

    #delete alien files in demonstration module
    allowed_documents = ['evidence', 'instruments','demonstration_review','demonstration_feedback']
    delete_google_drive_files(row['demonstration_folder'], allowed_documents)

    #delete alien files in report module
    allowed_documents = ['evidence', 'instruments','report_review','report_feedback']
    delete_google_drive_files(row['reports_folder'], allowed_documents)

    #delete alien files in exam module
    allowed_documents = ['formatives', 'summatives','presentation_review','presentation_feedback']
    delete_google_drive_files(row['exams_folder'], allowed_documents)
    
    #log success
    print(f'{row["poe_folder_title"]}: Finished Cleaning')
# Out:
# Adam Saul David Becker: Starting Cleaning
# Adam Saul David Becker: Finished Cleaning
# Abdur-Raheem Lee: Starting Cleaning
# Abdur-Raheem Lee: Finished Cleaning
# Abdullah Naseem Ebrahim: Starting Cleaning
# Abdullah Naseem Ebrahim: Finished Cleaning
# Antonio Joseph Gioio: Starting Cleaning
# Antonio Joseph Gioio: Finished Cleaning
# Abigail Hlalele: Starting Cleaning
# Abigail Hlalele: Finished Cleaning
# Aidan Josias: Starting Cleaning
# Aidan Josias: Finished Cleaning
# Majane Alex Thotse: Starting Cleaning
# Majane Alex Thotse: Finished Cleaning
# Andreas Gert Möller: Starting Cleaning
# Andreas Gert Möller: Finished Cleaning
# Adin Anton Nell: Starting Cleaning
# Adin Anton Nell: Finished Cleaning
# Anza Tshilidzi Michael Mugwabana: Starting Cleaning
# Anza Tshilidzi Michael Mugwabana: Finished Cleaning
# Andiswa Sbusisiwe Nombela: Starting Cleaning
# Andiswa Sbusisiwe Nombela: Finished Cleaning
# Angela Patrice Pelobello: Starting Cleaning
# Angela Patrice Pelobello: Finished Cleaning
# Aidan Miguel Sardie: Starting Cleaning
# Aidan Miguel Sardie: Finished Cleaning
# Anele Siguqa: Starting Cleaning
# Anele Siguqa: Finished Cleaning
# Balekane Kodi: Starting Cleaning
# Balekane Kodi: Finished Cleaning
# Baby Mulaudzi: Starting Cleaning
# Baby Mulaudzi: Finished Cleaning
# Barnard Izak Christian Steyn: Starting Cleaning
# Barnard Izak Christian Steyn: Finished Cleaning
# Bernard Botes: Starting Cleaning
# Bernard Botes: Finished Cleaning
# Benedict Sandile Dube: Starting Cleaning
# Benedict Sandile Dube: Finished Cleaning
# Bheki Mlangeni: Starting Cleaning
# Bheki Mlangeni: Finished Cleaning
# Bianca Daniels: Starting Cleaning
# Bianca Daniels: Finished Cleaning
# Basil Mokgadi Kganyago: Starting Cleaning
# Basil Mokgadi Kganyago: Finished Cleaning
# Bongiwe Xolelwa Maboke: Starting Cleaning
# Bongiwe Xolelwa Maboke: Finished Cleaning
# Boipelo Success Marima: Starting Cleaning
# Boipelo Success Marima: Finished Cleaning
# Byron Andrew Thompson: Starting Cleaning
# Byron Andrew Thompson: Finished Cleaning
# Cathrine Lebogang Bywang: Starting Cleaning
# Cathrine Lebogang Bywang: Finished Cleaning
# Charney Lynn Essack: Starting Cleaning
# Charney Lynn Essack: Finished Cleaning
# Cole Skye Fortuin: Starting Cleaning
# Cole Skye Fortuin: Finished Cleaning
# Chandler Alan Jacobs: Starting Cleaning
# Chandler Alan Jacobs: Finished Cleaning
# Christie Eveleigh Marx: Starting Cleaning
# Christie Eveleigh Marx: Finished Cleaning
# Corban Kylib Loots: Starting Cleaning
# Corban Kylib Loots: Finished Cleaning
# Carah Annette Prinsloo: Starting Cleaning
# Carah Annette Prinsloo: Finished Cleaning
# Chantel Annah Skosana: Starting Cleaning
# Chantel Annah Skosana: Finished Cleaning
# Daisy Marizia Mangue: Starting Cleaning
# Daisy Marizia Mangue: Finished Cleaning
# Dean Davids: Starting Cleaning
# Dean Davids: Finished Cleaning
# Donald Tshepo Leshabane: Starting Cleaning
# Donald Tshepo Leshabane: Finished Cleaning
# Delight Phefadu: Starting Cleaning
# Delight Phefadu: Finished Cleaning
# Dylan Keith Ranger: Starting Cleaning
# Dylan Keith Ranger: Finished Cleaning
# Demaind Ubisi: Starting Cleaning
# Demaind Ubisi: Finished Cleaning
# Ethan Mark Alberts: Starting Cleaning
# Ethan Mark Alberts: Finished Cleaning
# Elliott William Scott Austin: Starting Cleaning
# Elliott William Scott Austin: Finished Cleaning
# Ethan Byron Johns: Starting Cleaning
# Ethan Byron Johns: Finished Cleaning
# Edward Atile Noko: Starting Cleaning
# Edward Atile Noko: Finished Cleaning
# Faheemah Patel: Starting Cleaning
# Faheemah Patel: Finished Cleaning
# Fikile Thamsanqa Dalixolo Mehlo: Starting Cleaning
# Fikile Thamsanqa Dalixolo Mehlo: Finished Cleaning
# Floyd Sizwe Mokoena: Starting Cleaning
# Floyd Sizwe Mokoena: Finished Cleaning
# Florah Nonzwi Weni: Starting Cleaning
# Florah Nonzwi Weni: Finished Cleaning
# Grant Joseph Fortune: Starting Cleaning
# Grant Joseph Fortune: Finished Cleaning
# George Gottfried Pauer: Starting Cleaning
# George Gottfried Pauer: Finished Cleaning
# Hassan Mohammed Khan: Starting Cleaning
# Hassan Mohammed Khan: Finished Cleaning
# Hiranya Michaela Naicker: Starting Cleaning
# Hiranya Michaela Naicker: Finished Cleaning
# Hulisani Rambau: Starting Cleaning
# Hulisani Rambau: Finished Cleaning
# Henry Stephanus Wessels: Starting Cleaning
# Henry Stephanus Wessels: Finished Cleaning
# Issa Ruhullah Kalonji: Starting Cleaning
# Issa Ruhullah Kalonji: Finished Cleaning
# Ikraam Azhar Mayet: Starting Cleaning
# Ikraam Azhar Mayet: Finished Cleaning
# Isaac Kagiso Mogano Mogano: Starting Cleaning
# Isaac Kagiso Mogano Mogano: Finished Cleaning
# Isaac Biyabonga Mthimunye: Starting Cleaning
# Isaac Biyabonga Mthimunye: Finished Cleaning
# Pieter Andries Christiaan Pretorius: Starting Cleaning
# Pieter Andries Christiaan Pretorius: Finished Cleaning
# Ian Prins: Starting Cleaning
# Ian Prins: Finished Cleaning
# Junaid Abderoof: Starting Cleaning
# Junaid Abderoof: Finished Cleaning
# Jade Armstrong: Starting Cleaning
# Jade Armstrong: Finished Cleaning
# Jayden Williams: Starting Cleaning
# Jayden Williams: Finished Cleaning
# Jude Marshall Coates: Starting Cleaning
# Jude Marshall Coates: Finished Cleaning
# Jason Kokot: Starting Cleaning
# Jason Kokot: Finished Cleaning
# Jayson Aron Manganyi: Starting Cleaning
# Jayson Aron Manganyi: Finished Cleaning
# Jafta Mataboge: Starting Cleaning
# Jafta Mataboge: Finished Cleaning
# Jason Timothy Mather: Starting Cleaning
# Jason Timothy Mather: Finished Cleaning
# Joseph Masipa Mohale: Starting Cleaning
# Joseph Masipa Mohale: Finished Cleaning
# Ditokelo Jonas Motebejane: Starting Cleaning
# Ditokelo Jonas Motebejane: Finished Cleaning
# Joshua Lee Overton: Starting Cleaning
# Joshua Lee Overton: Finished Cleaning
# Joshua Philip Roy: Starting Cleaning
# Joshua Philip Roy: Finished Cleaning
# Jamie Stewart: Starting Cleaning
# Jamie Stewart: Finished Cleaning
# Jaques Trichardt: Starting Cleaning
# Jaques Trichardt: Finished Cleaning
# Koelthum Arend: Starting Cleaning
# Koelthum Arend: Finished Cleaning
# Keandra Nicolette Louise Bintcliffe: Starting Cleaning
# Keandra Nicolette Louise Bintcliffe: Finished Cleaning
# Kaylan Leigh Dennis: Starting Cleaning
# Kaylan Leigh Dennis: Finished Cleaning
# Kyle Fortuin: Starting Cleaning
# Kyle Fortuin: Finished Cleaning
# Khwezi Luthuli: Starting Cleaning
# Khwezi Luthuli: Finished Cleaning
# Kayden Dillon Kara: Starting Cleaning
# Kayden Dillon Kara: Finished Cleaning
# Kamogelo Mbali Khumalo: Starting Cleaning
# Kamogelo Mbali Khumalo: Finished Cleaning
# Karabo Sekgothe Mampuru: Starting Cleaning
# Karabo Sekgothe Mampuru: Finished Cleaning
# Kgotlelelo Masenamela: Starting Cleaning
# Kgotlelelo Masenamela: Finished Cleaning
# Katlego Relebogile Mokoena: Starting Cleaning
# Katlego Relebogile Mokoena: Finished Cleaning
# Kgothatso Stephen Mothibe: Starting Cleaning
# Kgothatso Stephen Mothibe: Finished Cleaning
# Katlego Mthunzi: Starting Cleaning
# Katlego Mthunzi: Finished Cleaning
# Khulekani Mpendulo Nkosi: Starting Cleaning
# Khulekani Mpendulo Nkosi: Finished Cleaning
# Liam Riccardo Chalmers: Starting Cleaning
# Liam Riccardo Chalmers: Finished Cleaning
# Lerato Makoanyane: Starting Cleaning
# Lerato Makoanyane: Finished Cleaning
# Lerato Mohlala: Starting Cleaning
# Lerato Mohlala: Finished Cleaning
# Lehlogonolo Lebogo: Starting Cleaning
# Lehlogonolo Lebogo: Finished Cleaning
# Lloyd Nhlanhla Ndhlovu: Starting Cleaning
# Lloyd Nhlanhla Ndhlovu: Finished Cleaning
# Lekau Frans Mamabolo: Starting Cleaning
# Lekau Frans Mamabolo: Finished Cleaning
# Kamohelo Lesedi Matsabu: Starting Cleaning
# Kamohelo Lesedi Matsabu: Finished Cleaning
# Lwanele Mduduzi Mayimele: Starting Cleaning
# Lwanele Mduduzi Mayimele: Finished Cleaning
# Lilo Moykweni: Starting Cleaning
# Lilo Moykweni: Finished Cleaning
# Lusanda Natasia Ngqose: Starting Cleaning
# Lusanda Natasia Ngqose: Finished Cleaning
# Lisa Nolte: Starting Cleaning
# Lisa Nolte: Finished Cleaning
# Londiwe Ntshele: Starting Cleaning
# Londiwe Ntshele: Finished Cleaning
# Lorenzo Valentino Mcmaster: Starting Cleaning
# Lorenzo Valentino Mcmaster: Finished Cleaning
# Lebohang Phatsoane: Starting Cleaning
# Lebohang Phatsoane: Finished Cleaning
# Leigh Glenda Stanley: Starting Cleaning
# Leigh Glenda Stanley: Finished Cleaning
# Luthando Timothy Siphosoxolo Zaze: Starting Cleaning
# Luthando Timothy Siphosoxolo Zaze: Finished Cleaning
# Matthew James Jansen: Starting Cleaning
# Matthew James Jansen: Finished Cleaning
# Mmathabo Pule: Starting Cleaning
# Mmathabo Pule: Finished Cleaning
# Mbali Komape: Starting Cleaning
# Mbali Komape: Finished Cleaning
# Marc Botha: Starting Cleaning
# Marc Botha: Finished Cleaning
# Marius De Jager: Starting Cleaning
# Marius De Jager: Finished Cleaning
# Mpho Futjane: Starting Cleaning
# Mpho Futjane: Finished Cleaning
# Maxine Tiffany Gillwald: Starting Cleaning
# Maxine Tiffany Gillwald: Finished Cleaning
# Matthew Brian Johannisen: Starting Cleaning
# Matthew Brian Johannisen: Finished Cleaning
# Moswazi Petrus Malatji: Starting Cleaning
# Moswazi Petrus Malatji: Finished Cleaning
# Mbalenhle Pretty Malinga: Starting Cleaning
# Mbalenhle Pretty Malinga: Finished Cleaning
# Mbuso Ntsele Mehlomakulu: Starting Cleaning
# Mbuso Ntsele Mehlomakulu: Finished Cleaning
# Nephtally Moshabeshe Moshabeshe: Starting Cleaning
# Nephtally Moshabeshe Moshabeshe: Finished Cleaning
# Mangaliso Elvynn Mtembu: Starting Cleaning
# Mangaliso Elvynn Mtembu: Finished Cleaning
# Mnoto Mlotshwa Nyembe: Starting Cleaning
# Mnoto Mlotshwa Nyembe: Finished Cleaning
# Morglin Olivier: Starting Cleaning
# Morglin Olivier: Finished Cleaning
# Maalik Rayaan Rawoot: Starting Cleaning
# Maalik Rayaan Rawoot: Finished Cleaning
# Muhammad-Shameeg Salie: Starting Cleaning
# Muhammad-Shameeg Salie: Finished Cleaning
# Meitar Yehuda Segal: Starting Cleaning
# Meitar Yehuda Segal: Finished Cleaning
# Makoma Shadow Sekgota: Starting Cleaning
# Makoma Shadow Sekgota: Finished Cleaning
# Mudivhi Marcus Tshishivhiri: Starting Cleaning
# Mudivhi Marcus Tshishivhiri: Finished Cleaning
# Mogamat Muneer Miller: Starting Cleaning
# Mogamat Muneer Miller: Finished Cleaning
# Melt Matthys Van Schoor: Starting Cleaning
# Melt Matthys Van Schoor: Finished Cleaning
# Ntuthuko Andile Bophela: Starting Cleaning
# Ntuthuko Andile Bophela: Finished Cleaning
# Nceba Lunga Lunga Kutloano Dumasi: Starting Cleaning
# Nceba Lunga Lunga Kutloano Dumasi: Finished Cleaning
# Naseemah Khan: Starting Cleaning
# Naseemah Khan: Finished Cleaning
# Nkosingiphile Isabel Nkosi: Starting Cleaning
# Nkosingiphile Isabel Nkosi: Finished Cleaning
# Nkosinathi Muziwakhe Radebe: Starting Cleaning
# Nkosinathi Muziwakhe Radebe: Finished Cleaning
# Nkosingiphile Neo Magubane: Starting Cleaning
# Nkosingiphile Neo Magubane: Finished Cleaning
# Nkosikhona Mzobanzi Mnguni: Starting Cleaning
# Nkosikhona Mzobanzi Mnguni: Finished Cleaning
# Niyaaz Mohammed Moosa: Starting Cleaning
# Niyaaz Mohammed Moosa: Finished Cleaning
# Nwabisa Ndengezi: Starting Cleaning
# Nwabisa Ndengezi: Finished Cleaning
# Ntsikelelo Camagu Ngcai: Starting Cleaning
# Ntsikelelo Camagu Ngcai: Finished Cleaning
# Nobantu Hope Gumbi: Starting Cleaning
# Nobantu Hope Gumbi: Finished Cleaning
# Nomsa Nxele: Starting Cleaning
# Nomsa Nxele: Finished Cleaning
# Nomthandazo Rose Thabethe: Starting Cleaning
# Nomthandazo Rose Thabethe: Finished Cleaning
# Nhlanhla Themba: Starting Cleaning
# Nhlanhla Themba: Finished Cleaning
# Naeem Thomas: Starting Cleaning
# Naeem Thomas: Finished Cleaning
# Ntshwara Princess Lamola: Starting Cleaning
# Ntshwara Princess Lamola: Finished Cleaning
# Ntiyiso Innocuous Maluleke: Starting Cleaning
# Ntiyiso Innocuous Maluleke: Finished Cleaning
# Oarabile Sebotse Moima: Starting Cleaning
# Oarabile Sebotse Moima: Finished Cleaning
# Oagile Segobaetso: Starting Cleaning
# Oagile Segobaetso: Finished Cleaning
# Paulo Filipe Goncalves Fernandes: Starting Cleaning
# Paulo Filipe Goncalves Fernandes: Finished Cleaning
# Pheladi Katlego Mabitsela: Starting Cleaning
# Pheladi Katlego Mabitsela: Finished Cleaning
# Phumza Mgaguli: Starting Cleaning
# Phumza Mgaguli: Finished Cleaning
# Piet Thulani Mahlangu: Starting Cleaning
# Piet Thulani Mahlangu: Finished Cleaning
# Pleasure Nyakane: Starting Cleaning
# Pleasure Nyakane: Finished Cleaning
# Pravir Rama: Starting Cleaning
# Pravir Rama: Finished Cleaning
# Raees Aziz Muhammad: Starting Cleaning
# Raees Aziz Muhammad: Finished Cleaning
# Nicolaas Johannes Roodt Brummer: Starting Cleaning
# Nicolaas Johannes Roodt Brummer: Finished Cleaning
# Rorisang Mmafoka Monatisa: Starting Cleaning
# Rorisang Mmafoka Monatisa: Finished Cleaning
# Rhys John Owen: Starting Cleaning
# Rhys John Owen: Finished Cleaning
# Regomoditswe Senne: Starting Cleaning
# Regomoditswe Senne: Finished Cleaning
# Rulof Van Der Merwe: Starting Cleaning
# Rulof Van Der Merwe: Finished Cleaning
# Shuaib Abvajee: Starting Cleaning
# Shuaib Abvajee: Finished Cleaning
# Sibusiso Abram Nkosi: Starting Cleaning
# Sibusiso Abram Nkosi: Finished Cleaning
# Sihle Dubazana: Starting Cleaning
# Sihle Dubazana: Finished Cleaning
# Sarah Rachael Gerber: Starting Cleaning
# Sarah Rachael Gerber: Finished Cleaning
# Innocent Sive Sandla: Starting Cleaning
# Innocent Sive Sandla: Finished Cleaning
# Sinethemba Luthango: Starting Cleaning
# Sinethemba Luthango: Finished Cleaning
# Ntlopo Shadrack Mabitsela: Starting Cleaning
# Ntlopo Shadrack Mabitsela: Finished Cleaning
# Siphesihle Manana: Starting Cleaning
# Siphesihle Manana: Finished Cleaning
# Sarah Mapula Matsena: Starting Cleaning
# Sarah Mapula Matsena: Finished Cleaning
# Sipho Mciwa: Starting Cleaning
# Sipho Mciwa: Finished Cleaning
# Sphelele Ayanda Msweli: Starting Cleaning
# Sphelele Ayanda Msweli: Finished Cleaning
# Siyabonga Thanks Mzimela: Starting Cleaning
# Siyabonga Thanks Mzimela: Finished Cleaning
# Sifiso Blessing Ncube: Starting Cleaning
# Sifiso Blessing Ncube: Finished Cleaning
# Shacquille Shane Niekerk: Starting Cleaning
# Shacquille Shane Niekerk: Finished Cleaning
# Seokamela David Ntjobokoane: Starting Cleaning
# Seokamela David Ntjobokoane: Finished Cleaning
# Shukri Samaai: Starting Cleaning
# Shukri Samaai: Finished Cleaning
# Moegamat Salmaan Schmidt: Starting Cleaning
# Moegamat Salmaan Schmidt: Finished Cleaning
# Raisibe Regina Serakalala: Starting Cleaning
# Raisibe Regina Serakalala: Finished Cleaning
# Sphiwokuhle Sphelele Shandu: Starting Cleaning
# Sphiwokuhle Sphelele Shandu: Finished Cleaning
# Tee-Jay Demingas Bird: Starting Cleaning
# Tee-Jay Demingas Bird: Finished Cleaning
# Tebogo Tema: Starting Cleaning
# Tebogo Tema: Finished Cleaning
# Thato Innocent Sithole: Starting Cleaning
# Thato Innocent Sithole: Finished Cleaning
# Thobeka Sithole: Starting Cleaning
# Thobeka Sithole: Finished Cleaning
# Thato Liyaphila Kwayiba: Starting Cleaning
# Thato Liyaphila Kwayiba: Finished Cleaning
# Thato Lethetsa: Starting Cleaning
# Thato Lethetsa: Finished Cleaning
# Tlotlo Tshireletso Mokabo: Starting Cleaning
# Tlotlo Tshireletso Mokabo: Finished Cleaning
# Thabana Makae: Starting Cleaning
# Thabana Makae: Finished Cleaning
# Thabo Mathebula: Starting Cleaning
# Thabo Mathebula: Finished Cleaning
# Thandeka Angela Mngomezulu: Starting Cleaning
# Thandeka Angela Mngomezulu: Finished Cleaning
# Thato Mokhera Moletsane: Starting Cleaning
# Thato Mokhera Moletsane: Finished Cleaning
# Teboho Sylvester Moloi: Starting Cleaning
# Teboho Sylvester Moloi: Finished Cleaning
# Tshepo Matome Moshole: Starting Cleaning
# Tshepo Matome Moshole: Finished Cleaning
# Thandolwethu Linamandla Njili: Starting Cleaning
# Thandolwethu Linamandla Njili: Finished Cleaning
# Tarak Pema: Starting Cleaning
# Tarak Pema: Finished Cleaning
# Tlali Raymond Radebe: Starting Cleaning
# Tlali Raymond Radebe: Finished Cleaning
# Tokollo Motlohi Ramabina: Starting Cleaning
# Tokollo Motlohi Ramabina: Finished Cleaning
# Tahir-Mahmood Rhoda: Starting Cleaning
# Tahir-Mahmood Rhoda: Finished Cleaning
# Thembinkosi Xolani Sithole: Starting Cleaning
# Thembinkosi Xolani Sithole: Finished Cleaning
# Tshiamo Affectionate Tranquil Lephale: Starting Cleaning
# Tshiamo Affectionate Tranquil Lephale: Finished Cleaning
# Tsholofelo Madela: Starting Cleaning
# Tsholofelo Madela: Finished Cleaning
# Thabang Gift Soulo: Starting Cleaning
# Thabang Gift Soulo: Finished Cleaning
# Nathi Gregory Xolani Khoba: Starting Cleaning
# Nathi Gregory Xolani Khoba: Finished Cleaning
# Montsheng Violet Loti: Starting Cleaning
# Montsheng Violet Loti: Finished Cleaning
# Vusmuzi Gift Pekane: Starting Cleaning
# Vusmuzi Gift Pekane: Finished Cleaning
# Isaac Vusi Sithole: Starting Cleaning
# Isaac Vusi Sithole: Finished Cleaning
# Vuyo Titi: Starting Cleaning
# Vuyo Titi: Finished Cleaning
# Wendonn Shane Butler: Starting Cleaning
# Wendonn Shane Butler: Finished Cleaning
# Warren Maxhawe Magagula: Starting Cleaning
# Warren Maxhawe Magagula: Finished Cleaning
# Wilson Kolana Makoae: Starting Cleaning
# Wilson Kolana Makoae: Finished Cleaning
# Wren Keanan Adams: Starting Cleaning
# Wren Keanan Adams: Finished Cleaning
# Wesley Luke Van Rooi: Starting Cleaning
# Wesley Luke Van Rooi: Finished Cleaning
# Xolani Cyril Ndlangisa: Starting Cleaning
# Xolani Cyril Ndlangisa: Finished Cleaning
# Xolisile Likhy Tshabalala: Starting Cleaning
# Xolisile Likhy Tshabalala: Finished Cleaning
# Yanga Mac Nodliwa: Starting Cleaning
# Yanga Mac Nodliwa: Finished Cleaning
# Yonwabisa Lithelihle Zwane: Starting Cleaning
# Yonwabisa Lithelihle Zwane: Finished Cleaning
# Zenani Kagiso Zwane: Starting Cleaning
# Zenani Kagiso Zwane: Finished Cleaning
# Zachary Pierce Glanville: Starting Cleaning
# Zachary Pierce Glanville: Finished Cleaning
# Zanele Fortunate Manyathi: Starting Cleaning
# Zanele Fortunate Manyathi: Finished Cleaning
# Zamanguni Ningi Mbali Mfeka: Starting Cleaning
# Zamanguni Ningi Mbali Mfeka: Finished Cleaning
# Zaid Saloojee: Starting Cleaning
# Zaid Saloojee: Finished Cleaning
# Damian Viljoen: Starting Cleaning
# Damian Viljoen: Finished Cleaning
# Sebaratlane Musa Mashaba: Starting Cleaning
# Sebaratlane Musa Mashaba: Finished Cleaning
